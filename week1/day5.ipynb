# %% [markdown]
# # A full business solution
#
# ## Now we will take our project from Day 1 to the next level
#
# ### BUSINESS CHALLENGE:
#
# Create a product that builds a Brochure for a company to be used for prospective clients, investors and potential recruits.
#
# We will be provided a company name and their primary website.
#
# See the end of this notebook for examples of real-world business applications.
#
# And remember: I'm always available if you have problems or ideas! Please do reach out.

# %%
# imports
# If these fail, please check you're running from an 'activated' environment with (llms) in the command prompt

import os
import requests
import json
from typing import List
from dotenv import load_dotenv
from bs4 import BeautifulSoup
from IPython.display import Markdown, display, update_display
from openai import OpenAI

# %%
# Initialize and constants

load_dotenv(override=True)
api_key = os.getenv('OPENAI_API_KEY')

if api_key and api_key.startswith('sk-proj-') and len(api_key)>10:
    print("API key looks good so far")
else:
    print("There might be a problem with your API key? Please visit the troubleshooting notebook!")
    
MODEL = 'gpt-4o-mini'
openai = OpenAI()
# Out:
# API key looks good so far

# %%
# A class to represent a Webpage

# Some websites need you to use proper headers when fetching them:
headers = {
 "User-Agent": "Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/117.0.0.0 Safari/537.36"
}

class Website:
    """
    A utility class to represent a Website that we have scraped, now with links
    """

    def __init__(self, url):
        self.url = url
        response = requests.get(url, headers=headers)
        self.body = response.content
        soup = BeautifulSoup(self.body, 'html.parser')
        self.title = soup.title.string if soup.title else "No title found"
        if soup.body:
            for irrelevant in soup.body(["script", "style", "img", "input"]):
                irrelevant.decompose()
            self.text = soup.body.get_text(separator="\n", strip=True)
        else:
            self.text = ""
        links = [link.get('href') for link in soup.find_all('a')]
        self.links = [link for link in links if link]

    def get_contents(self):
        return f"Webpage Title:\n{self.title}\nWebpage Contents:\n{self.text}\n\n"

# %%
ed = Website("https://edwarddonner.com")
ed.links
# Out:
# ['https://edwarddonner.com/',
#  'https://edwarddonner.com/connect-four/',
#  'https://edwarddonner.com/outsmart/',
#  'https://edwarddonner.com/about-me-and-about-nebula/',
#  'https://edwarddonner.com/posts/',
#  'https://edwarddonner.com/',
#  'https://news.ycombinator.com',
#  'https://nebula.io/?utm_source=ed&utm_medium=referral',
#  'https://www.prnewswire.com/news-releases/wynden-stark-group-acquires-nyc-venture-backed-tech-startup-untapt-301269512.html',
#  'https://patents.google.com/patent/US20210049536A1/',
#  'https://www.linkedin.com/in/eddonner/',
#  'https://edwarddonner.com/2025/05/28/connecting-my-courses-become-an-llm-expert-and-leader/',
#  'https://edwarddonner.com/2025/05/28/connecting-my-courses-become-an-llm-expert-and-leader/',
#  'https://edwarddonner.com/2025/05/18/2025-ai-executive-briefing/',
#  'https://edwarddonner.com/2025/05/18/2025-ai-executive-briefing/',
#  'https://edwarddonner.com/2025/04/21/the-complete-agentic-ai-engineering-course/',
#  'https://edwarddonner.com/2025/04/21/the-complete-agentic-ai-engineering-course/',
#  'https://edwarddonner.com/2025/01/23/llm-workshop-hands-on-with-agents-resources/',
#  'https://edwarddonner.com/2025/01/23/llm-workshop-hands-on-with-agents-resources/',
#  'https://edwarddonner.com/',
#  'https://edwarddonner.com/connect-four/',
#  'https://edwarddonner.com/outsmart/',
#  'https://edwarddonner.com/about-me-and-about-nebula/',
#  'https://edwarddonner.com/posts/',
#  'mailto:hello@mygroovydomain.com',
#  'https://www.linkedin.com/in/eddonner/',
#  'https://twitter.com/edwarddonner',
#  'https://www.facebook.com/edward.donner.52']

# %% [markdown]
# ## First step: Have GPT-4o-mini figure out which links are relevant
#
# ### Use a call to gpt-4o-mini to read the links on a webpage, and respond in structured JSON.
# It should decide which links are relevant, and replace relative links such as "/about" with "https://company.com/about".
# We will use "one shot prompting" in which we provide an example of how it should respond in the prompt.
#
# This is an excellent use case for an LLM, because it requires nuanced understanding. Imagine trying to code this without LLMs by parsing and analyzing the webpage - it would be very hard!
#
# Sidenote: there is a more advanced technique called "Structured Outputs" in which we require the model to respond according to a spec. We cover this technique in Week 8 during our autonomous Agentic AI project.

# %%
link_system_prompt = "You are provided with a list of links found on a webpage. \
You are able to decide which of the links would be most relevant to include in a brochure about the company, \
such as links to an About page, or a Company page, or Careers/Jobs pages.\n"
link_system_prompt += "You should respond in JSON as in this example:"
link_system_prompt += """
{
    "links": [
        {"type": "about page", "url": "https://full.url/goes/here/about"},
        {"type": "careers page": "url": "https://another.full.url/careers"}
    ]
}
"""

# %%
print(link_system_prompt)
# Out:
# You are provided with a list of links found on a webpage. You are able to decide which of the links would be most relevant to include in a brochure about the company, such as links to an About page, or a Company page, or Careers/Jobs pages.
# You should respond in JSON as in this example:
# {
#     "links": [
#         {"type": "about page", "url": "https://full.url/goes/here/about"},
#         {"type": "careers page": "url": "https://another.full.url/careers"}
#     ]
# }

# %%
def get_links_user_prompt(website):
    user_prompt = f"Here is the list of links on the website of {website.url} - "
    user_prompt += "please decide which of these are relevant web links for a brochure about the company, respond with the full https URL in JSON format. \
Do not include Terms of Service, Privacy, email links.\n"
    user_prompt += "Links (some might be relative links):\n"
    user_prompt += "\n".join(website.links)
    return user_prompt

# %%
print(get_links_user_prompt(ed))
# Out:
# Here is the list of links on the website of https://edwarddonner.com - please decide which of these are relevant web links for a brochure about the company, respond with the full https URL in JSON format. Do not include Terms of Service, Privacy, email links.
# Links (some might be relative links):
# https://edwarddonner.com/
# https://edwarddonner.com/connect-four/
# https://edwarddonner.com/outsmart/
# https://edwarddonner.com/about-me-and-about-nebula/
# https://edwarddonner.com/posts/
# https://edwarddonner.com/
# https://news.ycombinator.com
# https://nebula.io/?utm_source=ed&utm_medium=referral
# https://www.prnewswire.com/news-releases/wynden-stark-group-acquires-nyc-venture-backed-tech-startup-untapt-301269512.html
# https://patents.google.com/patent/US20210049536A1/
# https://www.linkedin.com/in/eddonner/
# https://edwarddonner.com/2025/05/28/connecting-my-courses-become-an-llm-expert-and-leader/
# https://edwarddonner.com/2025/05/28/connecting-my-courses-become-an-llm-expert-and-leader/
# https://edwarddonner.com/2025/05/18/2025-ai-executive-briefing/
# https://edwarddonner.com/2025/05/18/2025-ai-executive-briefing/
# https://edwarddonner.com/2025/04/21/the-complete-agentic-ai-engineering-course/
# https://edwarddonner.com/2025/04/21/the-complete-agentic-ai-engineering-course/
# https://edwarddonner.com/2025/01/23/llm-workshop-hands-on-with-agents-resources/
# https://edwarddonner.com/2025/01/23/llm-workshop-hands-on-with-agents-resources/
# https://edwarddonner.com/
# https://edwarddonner.com/connect-four/
# https://edwarddonner.com/outsmart/
# https://edwarddonner.com/about-me-and-about-nebula/
# https://edwarddonner.com/posts/
# mailto:hello@mygroovydomain.com
# https://www.linkedin.com/in/eddonner/
# https://twitter.com/edwarddonner
# https://www.facebook.com/edward.donner.52

# %%
def get_links(url):
    website = Website(url)
    response = openai.chat.completions.create(
        model=MODEL,
        messages=[
            {"role": "system", "content": link_system_prompt},
            {"role": "user", "content": get_links_user_prompt(website)}
      ],
        response_format={"type": "json_object"}
    )
    result = response.choices[0].message.content
    return json.loads(result)

# %%
# Anthropic has made their site harder to scrape, so I'm using HuggingFace..

huggingface = Website("https://huggingface.co")
huggingface.links
# Out:
# ['/',
#  '/models',
#  '/datasets',
#  '/spaces',
#  '/docs',
#  '/enterprise',
#  '/pricing',
#  '/login',
#  '/join',
#  '/spaces',
#  '/models',
#  '/deepseek-ai/DeepSeek-R1-0528',
#  '/google/gemma-3n-E4B-it-litert-preview',
#  '/Qwen/Qwen3-Embedding-0.6B-GGUF',
#  '/ResembleAI/chatterbox',
#  '/fishaudio/openaudio-s1-mini',
#  '/models',
#  '/spaces/ResembleAI/Chatterbox',
#  '/spaces/enzostvs/deepsite',
#  '/spaces/multimodalart/wan2-1-fast',
#  '/spaces/alexnasa/Chain-of-Zoom',
#  '/spaces/NihalGazi/Text-To-Speech-Unlimited',
#  '/spaces',
#  '/datasets/fka/awesome-chatgpt-prompts',
#  '/datasets/open-thoughts/OpenThoughts3-1.2M',
#  '/datasets/yandex/yambda',
#  '/datasets/Hcompany/WebClick',
#  '/datasets/open-r1/Mixture-of-Thoughts',
#  '/datasets',
#  '/join',
#  '/pricing#endpoints',
#  '/pricing#spaces',
#  '/pricing',
#  '/enterprise',
#  '/enterprise',
#  '/enterprise',
#  '/enterprise',
#  '/enterprise',
#  '/enterprise',
#  '/enterprise',
#  '/allenai',
#  '/facebook',
#  '/amazon',
#  '/google',
#  '/Intel',
#  '/microsoft',
#  '/grammarly',
#  '/Writer',
#  '/docs/transformers',
#  '/docs/diffusers',
#  '/docs/safetensors',
#  '/docs/huggingface_hub',
#  '/docs/tokenizers',
#  '/docs/trl',
#  '/docs/transformers.js',
#  '/docs/smolagents',
#  '/docs/peft',
#  '/docs/datasets',
#  '/docs/text-generation-inference',
#  '/docs/accelerate',
#  '/models',
#  '/datasets',
#  '/spaces',
#  '/changelog',
#  'https://endpoints.huggingface.co',
#  '/chat',
#  '/huggingface',
#  '/brand',
#  '/terms-of-service',
#  '/privacy',
#  'https://apply.workable.com/huggingface/',
#  'mailto:press@huggingface.co',
#  '/learn',
#  '/docs',
#  '/blog',
#  'https://discuss.huggingface.co',
#  'https://status.huggingface.co/',
#  'https://github.com/huggingface',
#  'https://twitter.com/huggingface',
#  'https://www.linkedin.com/company/huggingface/',
#  '/join/discord']

# %%
get_links("https://huggingface.co")
# Out:
# {'links': [{'type': 'about page', 'url': 'https://huggingface.co/huggingface'},
#   {'type': 'careers page', 'url': 'https://apply.workable.com/huggingface/'},
#   {'type': 'enterprise page', 'url': 'https://huggingface.co/enterprise'},
#   {'type': 'pricing page', 'url': 'https://huggingface.co/pricing'}]}

# %% [markdown]
# ## Second step: make the brochure!
#
# Assemble all the details into another prompt to GPT4-o

# %%
def get_all_details(url):
    result = "Landing page:\n"
    result += Website(url).get_contents()
    links = get_links(url)
    print("Found links:", links)
    for link in links["links"]:
        result += f"\n\n{link['type']}\n"
        result += Website(link["url"]).get_contents()
    return result

# %%
print(get_all_details("https://huggingface.co"))
# Out:
# Found links: {'links': [{'type': 'about page', 'url': 'https://huggingface.co/huggingface'}, {'type': 'careers page', 'url': 'https://apply.workable.com/huggingface/'}, {'type': 'models page', 'url': 'https://huggingface.co/models'}, {'type': 'datasets page', 'url': 'https://huggingface.co/datasets'}, {'type': 'spaces page', 'url': 'https://huggingface.co/spaces'}, {'type': 'enterprise page', 'url': 'https://huggingface.co/enterprise'}, {'type': 'pricing page', 'url': 'https://huggingface.co/pricing'}, {'type': 'documentation page', 'url': 'https://huggingface.co/docs'}, {'type': 'blog page', 'url': 'https://huggingface.co/blog'}, {'type': 'community forum', 'url': 'https://discuss.huggingface.co'}, {'type': 'GitHub page', 'url': 'https://github.com/huggingface'}, {'type': 'Twitter page', 'url': 'https://twitter.com/huggingface'}, {'type': 'LinkedIn page', 'url': 'https://www.linkedin.com/company/huggingface/'}]}
# Landing page:
# Webpage Title:
# Hugging Face – The AI community building the future.
# Webpage Contents:
# Hugging Face
# Models
# Datasets
# Spaces
# Community
# Docs
# Enterprise
# Pricing
# Log In
# Sign Up
# The AI community building the future.
# The platform where the machine learning community collaborates on models, datasets, and applications.
# Explore AI Apps
# or
# Browse 1M+ models
# Trending on
# this week
# Models
# deepseek-ai/DeepSeek-R1-0528
# Updated
# 11 days ago
# •
# 97.1k
# •
# 1.88k
# google/gemma-3n-E4B-it-litert-preview
# Updated
# 14 days ago
# •
# 1.05k
# Qwen/Qwen3-Embedding-0.6B-GGUF
# Updated
# about 14 hours ago
# •
# 8.45k
# •
# 257
# ResembleAI/chatterbox
# Updated
# 10 days ago
# •
# 729
# fishaudio/openaudio-s1-mini
# Updated
# 7 days ago
# •
# 1.25k
# •
# 181
# Browse 1M+ models
# Spaces
# Running
# on
# Zero
# 922
# 922
# Chatterbox TTS
# 🍿
# Expressive Zeroshot TTS
# Running
# 7.83k
# 7.83k
# DeepSite
# 🐳
# Generate any application with DeepSeek
# Running
# on
# Zero
# 573
# 573
# Wan2.1 Fast
# 🎥
# Turn static images into animated videos
# Running
# on
# Zero
# 236
# 236
# Chain-of-Zoom
# 🚀
# Extreme Super-Resolution via Scale Autoregression
# Running
# 476
# 476
# Realistic Text To Speech Unlimited
# 🔥
# Free Text-To-Speech generator with Emotion control (OpenAI)
# Browse 400k+ applications
# Datasets
# fka/awesome-chatgpt-prompts
# Updated
# Jan 6
# •
# 20.9k
# •
# 7.89k
# open-thoughts/OpenThoughts3-1.2M
# Updated
# about 4 hours ago
# •
# 3.7k
# •
# 66
# yandex/yambda
# Updated
# 3 days ago
# •
# 39.6k
# •
# 153
# Hcompany/WebClick
# Updated
# about 4 hours ago
# •
# 3.56k
# •
# 45
# open-r1/Mixture-of-Thoughts
# Updated
# 14 days ago
# •
# 30.1k
# •
# 206
# Browse 250k+ datasets
# The Home of Machine Learning
# Create, discover and collaborate on ML better.
# The collaboration platform
# Host and collaborate on unlimited public models, datasets and applications.
# Move faster
# With the HF Open source stack.
# Explore all modalities
# Text, image, video, audio or even 3D.
# Build your portfolio
# Share your work with the world and build your ML profile.
# Sign Up
# Accelerate your ML
# We provide paid Compute and Enterprise solutions.
# Compute
# Deploy on optimized
# Inference Endpoints
# or update your
# Spaces applications
# to a GPU in a few clicks.
# View pricing
# Starting at $0.60/hour for GPU
# Enterprise
# Give your team the most advanced platform to build AI with enterprise-grade security, access controls and
# 			dedicated support.
# Getting started
# Starting at $20/user/month
# Single Sign-On
# Regions
# Priority Support
# Audit Logs
# Resource Groups
# Private Datasets Viewer
# More than 50,000 organizations are using Hugging Face
# Ai2
# Enterprise
# non-profit
# •
# 765 models
# •
# 3.39k followers
# AI at Meta
# Enterprise
# company
# •
# 2.15k models
# •
# 6.35k followers
# Amazon
# company
# •
# 20 models
# •
# 3.22k followers
# Google
# company
# •
# 997 models
# •
# 16.2k followers
# Intel
# company
# •
# 230 models
# •
# 2.62k followers
# Microsoft
# company
# •
# 386 models
# •
# 12.8k followers
# Grammarly
# Enterprise
# company
# •
# 10 models
# •
# 162 followers
# Writer
# Enterprise
# company
# •
# 22 models
# •
# 294 followers
# Our Open Source
# We are building the foundation of ML tooling with the community.
# Transformers
# 145,363
# State-of-the-art ML for PyTorch, TensorFlow, JAX
# Diffusers
# 29,297
# State-of-the-art Diffusion models in PyTorch
# Safetensors
# 3,298
# Safe way to store/distribute neural network weights
# Hub Python Library
# 2,675
# Python client to interact with the Hugging Face Hub
# Tokenizers
# 9,774
# Fast tokenizers optimized for research & production
# TRL
# 14,095
# Train transformers LMs with reinforcement learning
# Transformers.js
# 13,765
# State-of-the-art ML running directly in your browser
# smolagents
# 19,918
# Smol library to build great agents in Python
# PEFT
# 18,712
# Parameter-efficient finetuning for large language models
# Datasets
# 20,257
# Access & share datasets for any ML tasks
# Text Generation Inference
# 10,197
# Serve language models with TGI optimized toolkit
# Accelerate
# 8,814
# Train PyTorch models with multi-GPU, TPU, mixed precision
# System theme
# Website
# Models
# Datasets
# Spaces
# Changelog
# Inference Endpoints
# HuggingChat
# Company
# About
# Brand assets
# Terms of service
# Privacy
# Jobs
# Press
# Resources
# Learn
# Documentation
# Blog
# Forum
# Service Status
# Social
# GitHub
# Twitter
# LinkedIn
# Discord
#
#
#
# about page
# Webpage Title:
# huggingface (Hugging Face)
# Webpage Contents:
# Hugging Face
# Models
# Datasets
# Spaces
# Community
# Docs
# Enterprise
# Pricing
# Log In
# Sign Up
# Hugging Face
# Enterprise
# company
# Verified
# https://huggingface.co
# huggingface
# huggingface
# Activity Feed
# Follow
# 42,464
# AI & ML interests
# The AI community building the future.
# Recent Activity
# siro1
# new
# activity
# about 3 hours ago
# huggingface/documentation-images:
# accelerate-edit-fsdp2-fp8
# lysandre
# updated
# a dataset
# about 7 hours ago
# huggingface/transformers-metadata
# loubnabnl
# authored
# a paper
# 2 days ago
# The Common Pile v0.1: An 8TB Dataset of Public Domain and Openly
#   Licensed Text
# View all activity
# Articles
# Yay! Organizations can now publish blog Articles
# Jan 20
# •
# 45
# Team members
# 215
# +181
# +168
# +147
# +137
# +117
# Organization Card
# Community
# About org cards
# 👋 Hi!
# We are on a mission to democratize
# good
# machine learning, one commit at a time.
# If that sounds like something you should be doing, why don't you
# join us
# !
# For press enquiries, you can
# ✉️ contact our team here
# .
# Collections
# 1
# DistilBERT release
# Original DistilBERT model, checkpoints obtained from using teacher-student learning from the original BERT checkpoints.
# distilbert/distilbert-base-cased
# Fill-Mask
# •
# Updated
# May 6, 2024
# •
# 243k
# •
# •
# 48
# distilbert/distilbert-base-uncased
# Fill-Mask
# •
# Updated
# May 6, 2024
# •
# 12.5M
# •
# •
# 705
# distilbert/distilbert-base-multilingual-cased
# Fill-Mask
# •
# Updated
# May 6, 2024
# •
# 5.49M
# •
# 194
# distilbert/distilbert-base-uncased-finetuned-sst-2-english
# Text Classification
# •
# Updated
# Dec 19, 2023
# •
# 4.87M
# •
# •
# 777
# spaces
# 28
# Sort:
# 		Recently updated
# pinned
# Running
# on
# CPU Upgrade
# 5
# Hugging Face Fast
# 🏎
# Test your internet bandwidth to Hugging Face
# huggingface
# 4 days ago
# pinned
# Running
# 10
# Enterprise Hub
# 🔒
# Why you need it, how to get it
# huggingface
# May 3
# pinned
# Running
# 90
# Number Tokenization Blog
# 📈
# Explore how tokenization affects arithmetic in LLMs
# huggingface
# Dec 14, 2024
# Running
# 427
# AI Deadlines
# ⚡
# Organize project deadlines with AI assistance
# huggingface
# 1 day ago
# Running
# 180
# Inference Playground
# 🔋
# Set theme of the page based on user or system preferences
# huggingface
# 12 days ago
# Running
# 9
# Space Build
# 🐨
# Generate static files for spaces
# huggingface
# 25 days ago
# Expand
# 							28
# 								spaces
# models
# 16
# Sort:
# 		Recently updated
# huggingface/time-series-transformer-tourism-monthly
# Time Series Forecasting
# •
# Updated
# 16 days ago
# •
# 4.53k
# •
# 21
# huggingface/timesfm-tourism-monthly
# Updated
# Mar 31
# •
# 21
# •
# 2
# huggingface/CodeBERTa-language-id
# Text Classification
# •
# Updated
# Mar 29, 2024
# •
# 51.1k
# •
# •
# 62
# huggingface/falcon-40b-gptq
# Text Generation
# •
# Updated
# Jun 14, 2023
# •
# 23
# •
# 12
# huggingface/autoformer-tourism-monthly
# Updated
# May 24, 2023
# •
# 38.1k
# •
# 9
# huggingface/distilbert-base-uncased-finetuned-mnli
# Text Classification
# •
# Updated
# Mar 22, 2023
# •
# 377
# •
# 2
# huggingface/informer-tourism-monthly
# Updated
# Feb 24, 2023
# •
# 38.7k
# •
# 6
# huggingface/the-no-branch-repo
# Text-to-Image
# •
# Updated
# Feb 10, 2023
# •
# 19
# •
# 5
# huggingface/CodeBERTa-small-v1
# Fill-Mask
# •
# Updated
# Jun 27, 2022
# •
# 170k
# •
# •
# 81
# huggingface/test-model-repo
# Updated
# Nov 19, 2021
# •
# 1
# Expand
# 							16
# 								models
# datasets
# 34
# Sort:
# 		Recently updated
# huggingface/documentation-images
# Viewer
# •
# Updated
# about 3 hours ago
# •
# 52
# •
# 3.13M
# •
# 68
# huggingface/transformers-metadata
# Viewer
# •
# Updated
# about 7 hours ago
# •
# 1.68k
# •
# 1.36k
# •
# 25
# huggingface/policy-docs
# Viewer
# •
# Updated
# 6 days ago
# •
# 24
# •
# 1.92k
# •
# 11
# huggingface/electricity-production
# Viewer
# •
# Updated
# 18 days ago
# •
# 397
# •
# 119
# •
# 1
# huggingface/badges
# Viewer
# •
# Updated
# Apr 8
# •
# 1
# •
# 1.69M
# •
# 44
# huggingface/diffusers-metadata
# Viewer
# •
# Updated
# Mar 15
# •
# 69
# •
# 519
# •
# 7
# huggingface/gemini-results-new-cs-papers-2025-02-11-100-230-updated
# Viewer
# •
# Updated
# Feb 17
# •
# 130
# •
# 170
# huggingface/wiki_dpr
# Updated
# Feb 5
# •
# 242
# huggingface/paper-central-data
# Viewer
# •
# Updated
# Jan 4
# •
# 124k
# •
# 136
# •
# 9
# huggingface/community-science-paper-v2
# Viewer
# •
# Updated
# Dec 22, 2024
# •
# 5.03k
# •
# 84
# •
# 7
# Expand
# 							34
# 								datasets
# System theme
# Company
# TOS
# Privacy
# About
# Jobs
# Website
# Models
# Datasets
# Spaces
# Pricing
# Docs
#
#
#
# careers page
# Webpage Title:
# Hugging Face - Current Openings
# Webpage Contents:
#
#
#
#
# models page
# Webpage Title:
# Models - Hugging Face
# Webpage Contents:
# Hugging Face
# Models
# Datasets
# Spaces
# Community
# Docs
# Enterprise
# Pricing
# Log In
# Sign Up
# Edit Models filters
# Tasks
# Libraries
# Datasets
# Languages
# Licenses
# Other
# Multimodal
# Audio-Text-to-Text
# Image-Text-to-Text
# Visual Question Answering
# Document Question Answering
# Video-Text-to-Text
# Visual Document Retrieval
# Any-to-Any
# Computer Vision
# Depth Estimation
# Image Classification
# Object Detection
# Image Segmentation
# Text-to-Image
# Image-to-Text
# Image-to-Image
# Image-to-Video
# Unconditional Image Generation
# Video Classification
# Text-to-Video
# Zero-Shot Image Classification
# Mask Generation
# Zero-Shot Object Detection
# Text-to-3D
# Image-to-3D
# Image Feature Extraction
# Keypoint Detection
# Natural Language Processing
# Text Classification
# Token Classification
# Table Question Answering
# Question Answering
# Zero-Shot Classification
# Translation
# Summarization
# Feature Extraction
# Text Generation
# Text2Text Generation
# Fill-Mask
# Sentence Similarity
# Text Ranking
# Audio
# Text-to-Speech
# Text-to-Audio
# Automatic Speech Recognition
# Audio-to-Audio
# Audio Classification
# Voice Activity Detection
# Tabular
# Tabular Classification
# Tabular Regression
# Time Series Forecasting
# Reinforcement Learning
# Reinforcement Learning
# Robotics
# Other
# Graph Machine Learning
# Apply filters
# Models
# Full-text search
# Add filters
# Sort:
# 		Trending
# deepseek-ai/DeepSeek-R1-0528
# Text Generation
# •
# Updated
# 11 days ago
# •
# 97.1k
# •
# •
# 1.88k
# google/gemma-3n-E4B-it-litert-preview
# Image-Text-to-Text
# •
# Updated
# 14 days ago
# •
# 1.05k
# Qwen/Qwen3-Embedding-0.6B-GGUF
# Updated
# about 14 hours ago
# •
# 8.45k
# •
# 257
# ResembleAI/chatterbox
# Text-to-Speech
# •
# Updated
# 10 days ago
# •
# •
# 729
# fishaudio/openaudio-s1-mini
# Text-to-Speech
# •
# Updated
# 7 days ago
# •
# 1.25k
# •
# 181
# Qwen/Qwen3-Embedding-0.6B
# Feature Extraction
# •
# Updated
# 3 days ago
# •
# 27.1k
# •
# 160
# deepseek-ai/DeepSeek-R1-0528-Qwen3-8B
# Text Generation
# •
# Updated
# 11 days ago
# •
# 180k
# •
# •
# 714
# nvidia/Nemotron-Research-Reasoning-Qwen-1.5B
# Text Generation
# •
# Updated
# 5 days ago
# •
# 3.45k
# •
# 140
# lerobot/smolvla_base
# Robotics
# •
# Updated
# 5 days ago
# •
# 2.87k
# •
# 131
# openbmb/MiniCPM4-8B
# Text Generation
# •
# Updated
# 3 days ago
# •
# 1.1k
# •
# 130
# osmosis-ai/Osmosis-Structure-0.6B
# Updated
# about 3 hours ago
# •
# 1.13k
# •
# 303
# rednote-hilab/dots.llm1.inst
# Text Generation
# •
# Updated
# about 8 hours ago
# •
# 725
# •
# 110
# Hcompany/Holo1-7B
# Image-Text-to-Text
# •
# Updated
# 5 days ago
# •
# 1.11k
# •
# 109
# google/gemma-3n-E2B-it-litert-preview
# Image-Text-to-Text
# •
# Updated
# 20 days ago
# •
# 350
# Qwen/Qwen3-Embedding-8B
# Feature Extraction
# •
# Updated
# 3 days ago
# •
# 7.78k
# •
# 91
# black-forest-labs/FLUX.1-dev
# Text-to-Image
# •
# Updated
# Aug 16, 2024
# •
# 1.91M
# •
# •
# 10.5k
# nvidia/Llama-3.1-Nemotron-Nano-VL-8B-V1
# Image-Text-to-Text
# •
# Updated
# about 4 hours ago
# •
# 3.6k
# •
# 85
# ByteDance-Seed/BAGEL-7B-MoT
# Any-to-Any
# •
# Updated
# 18 days ago
# •
# 10.6k
# •
# 995
# open-thoughts/OpenThinker3-7B
# Text Generation
# •
# Updated
# about 4 hours ago
# •
# 2.63k
# •
# •
# 84
# PlayHT/PlayDiffusion
# Updated
# 11 days ago
# •
# 96
# Qwen/Qwen3-Reranker-0.6B
# Text Ranking
# •
# Updated
# about 14 hours ago
# •
# 7.26k
# •
# 80
# arcee-ai/Homunculus
# Text Generation
# •
# Updated
# 6 days ago
# •
# 1.02k
# •
# 77
# lodestones/Chroma
# Text-to-Image
# •
# Updated
# 2 days ago
# •
# 798
# Qwen/Qwen3-Reranker-8B
# Text Ranking
# •
# Updated
# about 14 hours ago
# •
# 2.2k
# •
# 73
# Hcompany/Holo1-3B
# Image-Text-to-Text
# •
# Updated
# 5 days ago
# •
# 1.54k
# •
# 68
# fluxions/vui
# Text-to-Speech
# •
# Updated
# 4 days ago
# •
# 66
# google/medgemma-4b-it
# Image-Text-to-Text
# •
# Updated
# 19 days ago
# •
# 71.7k
# •
# 361
# FractalAIResearch/Fathom-R1-14B
# Text Generation
# •
# Updated
# 4 days ago
# •
# 14.4k
# •
# •
# 254
# tencent/HunyuanVideo-Avatar
# Image-to-Video
# •
# Updated
# 12 days ago
# •
# 169
# litert-community/Gemma3-1B-IT
# Text Generation
# •
# Updated
# 11 days ago
# •
# 104
# •
# 154
# System theme
# Company
# TOS
# Privacy
# About
# Jobs
# Website
# Models
# Datasets
# Spaces
# Pricing
# Docs
#
#
#
# datasets page
# Webpage Title:
# Hugging Face – The AI community building the future.
# Webpage Contents:
# Hugging Face
# Models
# Datasets
# Spaces
# Community
# Docs
# Enterprise
# Pricing
# Log In
# Sign Up
# Edit Datasets filters
# Main
# Tasks
# Libraries
# Languages
# Licenses
# Other
# Modalities
# 3D
# Audio
# Document
# Geospatial
# Image
# Tabular
# Text
# Time-series
# Video
# Size
# 			(rows)
# Reset Size
# < 1K
# > 1T
# Format
# json
# csv
# parquet
# imagefolder
# soundfolder
# webdataset
# text
# arrow
# Apply filters
# Datasets
# 417,665
# Full-text search
# Add filters
# Sort:
# 		Trending
# fka/awesome-chatgpt-prompts
# Viewer
# •
# Updated
# Jan 6
# •
# 203
# •
# 20.9k
# •
# 7.89k
# open-thoughts/OpenThoughts3-1.2M
# Viewer
# •
# Updated
# about 4 hours ago
# •
# 1.2M
# •
# 3.7k
# •
# 66
# yandex/yambda
# Viewer
# •
# Updated
# 3 days ago
# •
# 5.31B
# •
# 39.6k
# •
# 153
# Hcompany/WebClick
# Viewer
# •
# Updated
# about 4 hours ago
# •
# 1.64k
# •
# 3.56k
# •
# 45
# open-r1/Mixture-of-Thoughts
# Viewer
# •
# Updated
# 14 days ago
# •
# 699k
# •
# 30.1k
# •
# 206
# a-m-team/AM-DeepSeek-R1-0528-Distilled
# Preview
# •
# Updated
# about 6 hours ago
# •
# 2.5k
# •
# 43
# openbmb/Ultra-FineWeb
# Viewer
# •
# Updated
# 4 days ago
# •
# 1.29B
# •
# 33.8k
# •
# 155
# MiniMaxAI/SynLogic
# Viewer
# •
# Updated
# 5 days ago
# •
# 49.3k
# •
# 1.06k
# •
# 81
# PleIAs/common_corpus
# Viewer
# •
# Updated
# 5 days ago
# •
# 470M
# •
# 238k
# •
# 280
# common-pile/comma_v0.1_training_dataset
# Viewer
# •
# Updated
# 3 days ago
# •
# 784M
# •
# 7.15k
# •
# 21
# allenai/reward-bench-2
# Viewer
# •
# Updated
# 5 days ago
# •
# 1.87k
# •
# 730
# •
# 16
# microsoft/mediflow
# Viewer
# •
# Updated
# 10 days ago
# •
# 1.84M
# •
# 2.88k
# •
# 29
# JokerJan/MMR-VBench
# Viewer
# •
# Updated
# 5 days ago
# •
# 1.26k
# •
# 1.33k
# •
# 15
# snorkelai/Multi-Turn-Insurance-Underwriting
# Viewer
# •
# Updated
# 11 days ago
# •
# 100
# •
# 1.66k
# •
# 20
# DeepMount00/italian_conversations
# Viewer
# •
# Updated
# 2 days ago
# •
# 1k
# •
# 45
# •
# 12
# wikimedia/wikipedia
# Viewer
# •
# Updated
# Jan 9, 2024
# •
# 61.6M
# •
# 73.6k
# •
# 841
# gaia-benchmark/GAIA
# Updated
# Feb 13
# •
# 11.1k
# •
# 363
# HuggingFaceFW/fineweb
# Viewer
# •
# Updated
# Jan 31
# •
# 25B
# •
# 379k
# •
# 2.19k
# bigai-nlco/ReflectionEvo
# Viewer
# •
# Updated
# 6 days ago
# •
# 437k
# •
# 623
# •
# 11
# Josephgflowers/Finance-Instruct-500k
# Viewer
# •
# Updated
# Mar 1
# •
# 518k
# •
# 1.04k
# •
# 77
# openai/gsm8k
# Viewer
# •
# Updated
# Jan 4, 2024
# •
# 17.6k
# •
# 500k
# •
# 755
# roneneldan/TinyStories
# Viewer
# •
# Updated
# Aug 12, 2024
# •
# 2.14M
# •
# 25.6k
# •
# 678
# Jiahao004/DeepTheorem
# Viewer
# •
# Updated
# 3 days ago
# •
# 121k
# •
# 1.56k
# •
# 18
# futurehouse/ether0-benchmark
# Viewer
# •
# Updated
# 4 days ago
# •
# 325
# •
# 600
# •
# 8
# thivux/phoaudiobook
# Viewer
# •
# Updated
# about 17 hours ago
# •
# 1.04M
# •
# 944
# •
# 8
# tatsu-lab/alpaca
# Viewer
# •
# Updated
# May 22, 2023
# •
# 52k
# •
# 38.1k
# •
# 768
# HuggingFaceFW/fineweb-edu
# Viewer
# •
# Updated
# Jan 31
# •
# 3.3B
# •
# 128k
# •
# 691
# NousResearch/hermes-function-calling-v1
# Viewer
# •
# Updated
# Aug 30, 2024
# •
# 11.6k
# •
# 2.35k
# •
# 310
# FreedomIntelligence/medical-o1-reasoning-SFT
# Viewer
# •
# Updated
# Apr 22
# •
# 90.1k
# •
# 11k
# •
# 740
# nvidia/Llama-Nemotron-Post-Training-Dataset
# Viewer
# •
# Updated
# May 8
# •
# 3.91M
# •
# 11.1k
# •
# 499
# Previous
# 1
# 2
# 3
# ...
# 100
# Next
# System theme
# Company
# TOS
# Privacy
# About
# Jobs
# Website
# Models
# Datasets
# Spaces
# Pricing
# Docs
#
#
#
# spaces page
# Webpage Title:
# Spaces - Hugging Face
# Webpage Contents:
# Hugging Face
# Models
# Datasets
# Spaces
# Community
# Docs
# Enterprise
# Pricing
# Log In
# Sign Up
# Spaces
# ·
# The AI App Directory
# New Space
# Get PRO
# Learn more
# Image Generation
# Video Generation
# Text Generation
# Language Translation
# Speech Synthesis
# 3D Modeling
# Object Detection
# Text Analysis
# Image Editing
# Code Generation
# Question Answering
# Data Visualization
# Voice Cloning
# Background Removal
# Image Upscaling
# OCR
# Document Analysis
# Visual QA
# Image Captioning
# Chatbots
# Sentiment Analysis
# Text Summarization
# Music Generation
# Medical Imaging
# Financial Analysis
# Game AI
# Model Benchmarking
# Fine Tuning Tools
# Dataset Creation
# Pose Estimation
# Face Recognition
# Anomaly Detection
# Recommendation Systems
# Character Animation
# Style Transfer
# Image
# Spaces of the week
# 9 Jun 2025
# Filters
# (0)
# Sort:
# 		Relevance
# Running
# on
# Zero
# 922
# Chatterbox TTS
# 🍿
# Expressive Zeroshot TTS
# ResembleAI
# 11 days ago
# Running
# on
# Zero
# 93
# SoloSpeech
# 🎯
# State-of-the-art target speech extractor
# OpenSound
# 6 days ago
# Running
# 22
# WhiStress Demo
# 📉
# Transcribe speech and highlight emphasized words
# slprl
# 15 days ago
# Running
# on
# Zero
# 192
# OmniConsistency
# 🚀
# Generate styled image from reference image and external LoRA
# yiren98
# 12 days ago
# Running
# on
# Zero
# 236
# Chain-of-Zoom
# 🚀
# Extreme Super-Resolution via Scale Autoregression
# alexnasa
# 6 days ago
# Running
# 19
# auto-diffuser-config
# 🚀
# Generate optimized code for image generation tasks
# chansung
# 5 days ago
# Running
# 318
# Direct3D S2 V1.0 Demo
# 💻
# Generate 3D models with spatial sparse attention
# wushuang98
# 4 days ago
# Running
# 476
# Realistic Text To Speech Unlimited
# 🔥
# Free Text-To-Speech generator with Emotion control (OpenAI)
# NihalGazi
# 5 days ago
# All running apps, trending first
# Running
# on
# Zero
# 922
# Chatterbox TTS
# 🍿
# Expressive Zeroshot TTS
# ResembleAI
# 11 days ago
# Running
# 7.83k
# DeepSite
# 🐳
# Generate any application with DeepSeek
# enzostvs
# about 2 hours ago
# Running
# on
# Zero
# 573
# Wan2.1 Fast
# 🎥
# Turn static images into animated videos
# multimodalart
# 19 days ago
# Running
# on
# Zero
# 236
# Chain-of-Zoom
# 🚀
# Extreme Super-Resolution via Scale Autoregression
# alexnasa
# 6 days ago
# Running
# 476
# Realistic Text To Speech Unlimited
# 🔥
# Free Text-To-Speech generator with Emotion control (OpenAI)
# NihalGazi
# 5 days ago
# Running
# 132
# Conversational WebGPU
# 🚀
# webml-community
# 5 days ago
# Running
# 318
# Direct3D S2 V1.0 Demo
# 💻
# Generate 3D models with spatial sparse attention
# wushuang98
# 4 days ago
# Running
# on
# Zero
# 192
# OmniConsistency
# 🚀
# Generate styled image from reference image and external LoRA
# yiren98
# 12 days ago
# Running
# on
# Zero
# 93
# SoloSpeech
# 🎯
# State-of-the-art target speech extractor
# OpenSound
# 6 days ago
# Running
# 1.09k
# FLUX Pro Unlimited
# 🔥
# Use the FLUX-Pro model as much as you want.
# NihalGazi
# 1 day ago
# Running
# on
# Zero
# 723
# LTX Video Fast
# 🎥
# ultra-fast video model, LTX 0.9.7 13B distilled
# Lightricks
# 22 days ago
# Running
# on
# Zero
# 531
# NSFW Uncensored text to image
# 🎬
# NSFW Uncensored text to image for AI Limits
# Heartsync
# 4 days ago
# Running
# 66
# Dots Demo
# 💻
# Generate responses to text inputs
# rednote-hilab
# 4 days ago
# Running
# on
# CPU Upgrade
# 8.99k
# Kolors Virtual Try-On
# 👕
# Try on garments virtually using images
# Kwai-Kolors
# Sep 18, 2024
# Running
# on
# A10G
# 69
# PlayDiffusion
# 🎨
# Generate modified audio from text
# PlayHT
# 3 days ago
# Running
# on
# Zero
# 8.49k
# FLUX.1 [dev]
# 🖥
# Generate images from text prompts
# black-forest-labs
# Apr 16
# Running
# on
# CPU Upgrade
# 5.81k
# MTEB Leaderboard
# 🥇
# Embedding Leaderboard
# mteb
# Apr 17
# Running
# 51
# AI Marketing Content Generator
# 🎨
# An AI-powered tool made for content creators and marketers
# Agents-MCP-Hackathon
# about 7 hours ago
# Running
# 145
# Gradio Hackathon Registration 2025
# 🏢
# Gradio Agents & MCP Hackathon 2025 registration
# ysharma
# 3 days ago
# Running
# on
# Zero
# 114
# MIDJOURNEY
# 🏜
# MidJour | A RealVisXL_Turbo | IRL HI-Res Images Gen
# Dagfinn1962
# Jan 14
# Running
# on
# Zero
# 1.97k
# Background Removal
# 🌘
# Remove background from images
# not-lain
# 7 days ago
# Running
# on
# CPU Upgrade
# 10.3k
# AI Comic Factory
# 👩
# Create your own AI comic with a single prompt
# jbilcke-hf
# Oct 15, 2024
# Running
# on
# L4
# 547
# OpenAudio S1
# 🏆
# Generate audio from text
# fishaudio
# 3 days ago
# Running
# on
# CPU Upgrade
# 862
# Computer Agent
# 🖥
# Interact with an agent to perform web-based tasks
# smolagents
# 26 days ago
# Previous
# 1
# 2
# 3
# ...
# 100
# Next
# System theme
# Company
# TOS
# Privacy
# About
# Jobs
# Website
# Models
# Datasets
# Spaces
# Pricing
# Docs
#
#
#
# enterprise page
# Webpage Title:
# Enterprise Hub - Hugging Face
# Webpage Contents:
# Hugging Face
# Models
# Datasets
# Spaces
# Community
# Docs
# Enterprise
# Pricing
# Log In
# Sign Up
# Enterprise Hub
# Enterprise-ready version of the world’s leading AI platform
# Subscribe to
# Enterprise Hub
# from $20/user/month with your Hub organization
# Give your organization the most advanced platform to build AI with enterprise-grade security, access controls,
# 			dedicated support and more.
# Single Sign-On
# Connect securely to your identity provider with SSO integration.
# Regions
# Select, manage, and audit the location of your repository data.
# Audit Logs
# Stay in control with comprehensive logs that report on actions taken.
# Resource Groups
# Accurately manage access to repositories with granular access control.
# Token Management
# Centralized token control and custom approval policies for organization access.
# Analytics
# Track and analyze repository usage data in a single dashboard.
# Advanced Compute Options
# Increase scalability and performance with more compute options like ZeroGPU.
# ZeroGPU Quota Boost
# All organization members get 5x more ZeroGPU quota to get the most of Spaces.
# Private Datasets Viewer
# Enable the Dataset Viewer on your private datasets for easier collaboration.
# Advanced security
# Configure organization-wide security policies and default repository visibility.
# Billing
# Control your budget effectively with managed billing and yearly commit options.
# Priority Support
# Maximize your platform usage with priority support from the Hugging Face team.
# Extra Private Storage
# Get an additional 1 TB of private storage for each member of your organization (then $25/month per extra TB).
# Join the most forward-thinking AI organizations
# Everything you already know and love about Hugging Face in Enterprise mode.
# Subscribe to
# Enterprise Hub
# or
# Talk to sales
# NVIDIA
# Enterprise
# company
# •
# 393 models
# •
# 28.5k followers
# Shopify
# Enterprise
# company
# •
# 476 followers
# AMD
# Enterprise
# company
# •
# 142 models
# •
# 1.58k followers
# Arm
# Enterprise
# company
# •
# 213 followers
# Qwen
# Enterprise
# company
# •
# 289 models
# •
# 34.2k followers
# Xsolla
# Enterprise
# company
# •
# 137 followers
# Fidelity Investments
# Enterprise
# company
# •
# 150 followers
# Mercedes-Benz AG
# Enterprise
# company
# •
# 166 followers
# IBM Granite
# Enterprise
# company
# •
# 118 models
# •
# 1.85k followers
# Aledade Inc
# Enterprise
# company
# •
# 72 followers
# Chegg Inc
# Enterprise
# company
# •
# 87 followers
# Grammarly
# Enterprise
# company
# •
# 10 models
# •
# 162 followers
# MiniMax
# Enterprise
# company
# •
# 5 models
# •
# 723 followers
# Widn AI
# Enterprise
# company
# •
# 48 followers
# Infosys Limited
# Enterprise
# company
# •
# 2 models
# •
# 861 followers
# AI at Meta
# Enterprise
# company
# •
# 2.15k models
# •
# 6.35k followers
# Snowflake
# Enterprise
# company
# •
# 23 models
# •
# 536 followers
# Writer
# Enterprise
# company
# •
# 22 models
# •
# 294 followers
# ServiceNow
# Enterprise
# company
# •
# 509 followers
# ServiceNow-AI
# Enterprise
# company
# •
# 3 models
# •
# 287 followers
# Toyota Research Institute
# Enterprise
# company
# •
# 10 models
# •
# 118 followers
# Jusbrasil
# Enterprise
# company
# •
# 98 followers
# creditkarma
# Enterprise
# company
# •
# 70 followers
# H2O.ai
# Enterprise
# company
# •
# 71 models
# •
# 426 followers
# HiddenLayer
# Enterprise
# company
# •
# 1 model
# •
# 74 followers
# LinkedIn
# Enterprise
# company
# •
# 60 followers
# Lightricks
# Enterprise
# company
# •
# 13 models
# •
# 1.04k followers
# Stability AI
# Enterprise
# company
# •
# 107 models
# •
# 24.8k followers
# Meta Llama
# Enterprise
# company
# •
# 70 models
# •
# 47.3k followers
# Nerdy Face
# Enterprise
# company
# •
# 1 model
# •
# 300 followers
# Orange
# Enterprise
# company
# •
# 7 models
# •
# 230 followers
# Together
# Enterprise
# company
# •
# 33 models
# •
# 619 followers
# LiveRAG by AIIR
# Enterprise
# company
# •
# 130 followers
# Nutanix
# Enterprise
# company
# •
# 261 models
# •
# 110 followers
# Deutsche Telekom AG
# Enterprise
# company
# •
# 7 models
# •
# 150 followers
# TNG Technology Consulting GmbH
# Enterprise
# company
# •
# 4 models
# •
# 154 followers
# Technology Innovation Institute
# Enterprise
# company
# •
# 101 models
# •
# 1.43k followers
# Johnson & Johnson
# Enterprise
# company
# •
# 67 followers
# HyperCLOVA X
# Enterprise
# company
# •
# 3 models
# •
# 341 followers
# Skywork
# Enterprise
# company
# •
# 40 models
# •
# 715 followers
# Liquid AI
# Enterprise
# company
# •
# 199 followers
# BCG X
# Enterprise
# company
# •
# 40 followers
# Compliance & Certifications
# GDPR Compliant
# SOC 2 Type 2
# System theme
# Website
# Models
# Datasets
# Spaces
# Changelog
# Inference Endpoints
# HuggingChat
# Company
# About
# Brand assets
# Terms of service
# Privacy
# Jobs
# Press
# Resources
# Learn
# Documentation
# Blog
# Forum
# Service Status
# Social
# GitHub
# Twitter
# LinkedIn
# Discord
#
#
#
# pricing page
# Webpage Title:
# Hugging Face – Pricing
# Webpage Contents:
# Hugging Face
# Models
# Datasets
# Spaces
# Community
# Docs
# Enterprise
# Pricing
# Log In
# Sign Up
# Pricing
# Leveling up AI collaboration and compute.
# Users and organizations already use the Hub as a collaboration platform,
# we’re making it easy to seamlessly and scalably launch ML compute directly from the Hub.
# HF Hub
# Collaborate on Machine Learning
# Host unlimited public models, datasets
# Create unlimited orgs with no member limits
# Access the latest ML tools and open source
# Community support
# Forever
# Free
# PRO
# PRO Account
# Unlock advanced HF features
# ZeroGPU and Dev Mode for Spaces
# Free credits across all Inference Providers
# 10× Private storage capacity
# Show your support with a Pro badge
# Subscribe for
# $9
# /month
# Enterprise Hub
# Accelerate your AI roadmap
# SSO and SAML support
# Select data location with Storage Regions
# Precise actions reviews with Audit logs
# Granular access control with Resource groups
# Centralized token control and approval
# Dataset Viewer for private datasets
# Advanced compute options for Spaces
# 8× more ZeroGPU quota for all org members
# Deploy Inference on your own Infra
# Managed billing with yearly commits
# Priority support
# Starting at
# $20
# per user per month
# Spaces Hardware
# Upgrade your Space compute
# Free CPUs
# Build more advanced Spaces
# 7 optimized hardware available
# From CPU to GPU to Accelerators
# Starting at
# $0
# /hour
# Inference Endpoints
# Deploy models on fully managed infrastructure
# Deploy dedicated Endpoints in seconds
# Keep your costs low
# Fully-managed autoscaling
# Enterprise security
# Starting at
# $0.032
# /hour
# Need support to accelerate AI in your organization? View our
# Expert Support
# .
# Hugging Face Hub
# free
# The HF Hub is the central place to explore, experiment, collaborate and build technology with Machine
# 					Learning.
# Join the open source Machine Learning movement!
# →
# Sign Up
# Create with ML
# Packed with ML features, like model eval, dataset viewer and much more.
# Collaborate
# Git based and designed for collaboration at its core.
# Play and learn
# Learn by experimenting and sharing with our awesome community.
# Build your ML portfolio
# Share your work with the world and build your own ML profile.
# Spaces Hardware
# Starting at $0
# Spaces are one of the most popular ways to share ML applications and demos with the world.
# Upgrade your Spaces with our selection of custom on-demand hardware:
# →
# Get started with Spaces
# Name
# CPU
# Memory
# Accelerator
# VRAM
# Hourly price
# CPU Basic
# 2 vCPU
# 16 GB
# -
# -
# FREE
# CPU Upgrade
# 8 vCPU
# 32 GB
# -
# -
# $0.03
# Nvidia T4 - small
# 4 vCPU
# 15 GB
# Nvidia T4
# 16 GB
# $0.40
# Nvidia T4 - medium
# 8 vCPU
# 30 GB
# Nvidia T4
# 16 GB
# $0.60
# 1x Nvidia L4
# 8 vCPU
# 30 GB
# Nvidia L4
# 24 GB
# $0.80
# 4x Nvidia L4
# 48 vCPU
# 186 GB
# Nvidia L4
# 96 GB
# $3.80
# 1x Nvidia L40S
# 8 vCPU
# 62 GB
# Nvidia L4
# 48 GB
# $1.80
# 4x Nvidia L40S
# 48 vCPU
# 382 GB
# Nvidia L4
# 192 GB
# $8.30
# 8x Nvidia L40S
# 192 vCPU
# 1534 GB
# Nvidia L4
# 384 GB
# $23.50
# Nvidia A10G - small
# 4 vCPU
# 15 GB
# Nvidia A10G
# 24 GB
# $1.00
# Nvidia A10G - large
# 12 vCPU
# 46 GB
# Nvidia A10G
# 24 GB
# $1.50
# 2x Nvidia A10G - large
# 24 vCPU
# 92 GB
# Nvidia A10G
# 48 GB
# $3.00
# 4x Nvidia A10G - large
# 48 vCPU
# 184 GB
# Nvidia A10G
# 96 GB
# $5.00
# Nvidia A100 - large
# 12 vCPU
# 142 GB
# Nvidia A100
# 80 GB
# $4.00
# Custom
# on demand
# on demand
# on demand
# on demand
# on demand
# Spaces Persistent Storage
# All Spaces get ephemeral storage for free but you can upgrade and add persistent storage at any time.
# Name
# Storage
# Monthly price
# Small
# 20 GB
# $5
# Medium
# 150 GB
# $25
# Large
# 1 TB
# $100
# Building something cool as a side project? We also offer community GPU grants.
# Inference Endpoints
# Starting at $0.033/hour
# Inference Endpoints (dedicated) offers a secure production solution to easily deploy any ML model on dedicated
# 					and autoscaling infrastructure, right from the HF Hub.
# →
# Learn more
# CPU
# instances
# Provider
# Architecture
# vCPUs
# Memory
# Hourly rate
# aws
# Intel Sapphire Rapids
# 1
# 2GB
# $0.03
# 2
# 4GB
# $0.07
# 4
# 8GB
# $0.13
# 8
# 16GB
# $0.27
# 16
# 32GB
# $0.54
# azure
# Intel Xeon
# 1
# 2GB
# $0.06
# 2
# 4GB
# $0.12
# 4
# 8GB
# $0.24
# 8
# 16GB
# $0.48
# gcp
# Intel Sapphire Rapids
# 1
# 2GB
# $0.05
# 2
# 4GB
# $0.10
# 4
# 8GB
# $0.20
# 8
# 16GB
# $0.40
# Accelerator
# instances
# Provider
# Architecture
# Topology
# Accelerator Memory
# Hourly rate
# aws
# Inf2
# 															Neuron
# x1
# 14.5GB
# $0.75
# x12
# 760GB
# $12.00
# gcp
# TPU
# 															v5e
# 1x1
# 16GB
# $1.20
# 2x2
# 64GB
# $4.75
# 2x4
# 128GB
# $9.50
# GPU
# instances
# Provider
# Architecture
# GPUs
# GPU Memory
# Hourly rate
# aws
# NVIDIA T4
# 1
# 14GB
# $0.50
# 4
# 56GB
# $3.00
# aws
# NVIDIA L4
# 1
# 24GB
# $0.80
# 4
# 96GB
# $3.80
# aws
# NVIDIA L40S
# 1
# 48GB
# $1.80
# 4
# 192GB
# $8.30
# 8
# 384GB
# $23.50
# aws
# NVIDIA A10G
# 1
# 24GB
# $1.00
# 4
# 96GB
# $5.00
# aws
# NVIDIA A100
# 1
# 80GB
# $4.00
# 2
# 160GB
# $8.00
# 4
# 320GB
# $16.00
# 8
# 640GB
# $32.00
# aws
# NVIDIA H200
# 1
# 141GB
# $5.00
# 2
# 282GB
# $10.00
# 4
# 564GB
# $20.00
# 8
# 1128GB
# $40.00
# gcp
# NVIDIA T4
# 1
# 16GB
# $0.50
# gcp
# NVIDIA L4
# 1
# 24GB
# $0.70
# 4
# 96GB
# $3.80
# gcp
# NVIDIA A100
# 1
# 80GB
# $3.60
# 2
# 160GB
# $7.20
# 4
# 320GB
# $14.40
# 8
# 640GB
# $28.80
# gcp
# NVIDIA H100
# 1
# 80GB
# $10.00
# 2
# 160GB
# $20.00
# 4
# 320GB
# $40.00
# 8
# 640GB
# $80.00
# PRO Account
# PRO
# A monthly subscription to access powerful features.
# →
# Get PRO
# ($9/month)
# ZeroGPU
# : Get 8× usage quota and highest GPU queue priority
# Spaces Hosting
# : Create ZeroGPU Spaces with H200 hardware
# Spaces Dev Mode
# : Fast iterations via SSH/VS Code for Spaces
# Inference Providers
# : Get $2 included credits across all Inference Providers
# Dataset Viewer
# : Activate it on private datasets
# Blog Articles
# : Publish articles to the Hugging Face blog
# Social Posts
# : Share short updates with the community
# Features Preview
# : Get early access to upcoming
# 										features
# PRO
# Badge
# :
# 										Show your support on your profile
# System theme
# Website
# Models
# Datasets
# Spaces
# Changelog
# Inference Endpoints
# HuggingChat
# Company
# About
# Brand assets
# Terms of service
# Privacy
# Jobs
# Press
# Resources
# Learn
# Documentation
# Blog
# Forum
# Service Status
# Social
# GitHub
# Twitter
# LinkedIn
# Discord
#
#
#
# documentation page
# Webpage Title:
# Hugging Face - Documentation
# Webpage Contents:
# Hugging Face
# Models
# Datasets
# Spaces
# Community
# Docs
# Enterprise
# Pricing
# Log In
# Sign Up
# Documentations
# Hub & Client Libraries
# Hub
# Host Git-based models, datasets, and Spaces on the HF Hub
# Hub Python Library
# Python client to interact with the Hugging Face Hub
# Huggingface.js
# JavaScript libraries for Hugging Face with built-in TS types
# Tasks
# Explore demos, models, and datasets for any ML tasks
# Dataset viewer
# API for metadata, stats, and content of HF Hub datasets
# Deployment & Inference
# Inference Providers
# Call 200k+ models hosted by our 10+ Inference partners
# Inference Endpoints (dedicated)
# Deploy models on dedicated & fully managed infrastructure on HF
# Amazon SageMaker
# Train/deploy Transformers models with SageMaker/HF DLCs
# Text Generation Inference
# Serve language models with TGI optimized toolkit
# Text Embeddings Inference
# Serve embeddings models with TEI optimized toolkit
# Core ML Libraries
# Transformers
# State-of-the-art ML for PyTorch, TensorFlow, JAX
# Diffusers
# State-of-the-art Diffusion models in PyTorch
# Datasets
# Access & share datasets for any ML tasks
# Transformers.js
# State-of-the-art ML running directly in your browser
# Tokenizers
# Fast tokenizers optimized for research & production
# Evaluate
# Evaluate and compare models performance
# timm
# State-of-the-art vision models: layers, optimizers, and utilities
# Sentence Transformers
# Embeddings, Retrieval, and Reranking
# Training & Optimization
# PEFT
# Parameter-efficient finetuning for large language models
# Accelerate
# Train PyTorch models with multi-GPU, TPU, mixed precision
# Optimum
# Optimize HF Transformers for faster training/inference
# AWS Trainium & Inferentia
# Train/deploy Transformers/Diffusers on AWS
# TRL
# Train transformers LMs with reinforcement learning
# Safetensors
# Safe way to store/distribute neural network weights
# Bitsandbytes
# Optimize and quantize models with bitsandbytes
# Lighteval
# All-in-one toolkit to evaluate LLMs across multiple backends
# Collaboration & Extras
# Gradio
# Build ML demos and web apps with a few lines of Python
# smolagents
# Smol library to build great agents in Python
# LeRobot
# Making AI for Robotics more accessible with end-to-end learning
# AutoTrain
# AutoTrain API and UI for seamless model training
# Chat UI
# Open source chat frontend powering HuggingChat
# Leaderboards
# Create custom Leaderboards on Hugging Face
# Argilla
# Collaboration tool for building high-quality datasets
# Distilabel
# Framework for synthetic data generation and AI feedback
# Community
# Blog
# Learn
# Discord
# Forum
# Github
# System theme
# Company
# TOS
# Privacy
# About
# Jobs
# Website
# Models
# Datasets
# Spaces
# Pricing
# Docs
#
#
#
# blog page
# Webpage Title:
# Hugging Face – Blog
# Webpage Contents:
# Hugging Face
# Models
# Datasets
# Spaces
# Community
# Docs
# Enterprise
# Pricing
# Log In
# Sign Up
# Blog, Articles, and discussions
# New Article
# Everything
# community
# guide
# open source collab
# partnerships
# research
# NLP
# Audio
# CV
# RL
# ethics
# Diffusion
# Game Development
# RLHF
# Leaderboard
# Case Studies
# LeRobot
# ScreenSuite - The most comprehensive evaluation suite for GUI Agents!
# By
# a-mahla
# June 6, 2025
# •
# 26
# Community Articles
# view all
# Holo1: New family of GUI automation VLMs powering GUI agent Surfer-H
# By
# Hcompany
# and 1 other
# •
# 6 days ago
# •
# 61
# The Common Pile v0.1
# By
# stellaathena
# and 2 others
# •
# 3 days ago
# •
# 25
# Explore, Build, and Innovate AI Reasoning with NVIDIA’s Open Models and Recipes
# By
# nvidia
# and 2 others
# •
# 5 days ago
# •
# 19
# *Context Is Gold to Find the Gold Passage*:  Evaluating and Training Contextual Document Embeddings
# By
# manu
# and 1 other
# •
# 7 days ago
# •
# 23
# Announcing the Common Pile and Comma v0.1
# By
# common-pile
# •
# 3 days ago
# •
# 13
# xLSTM-based time series model TiRex  significantly outperforms competing models in forecasting accuracy
# By
# BobWue
# •
# 5 days ago
# •
# 12
# What if Your AI Conversations Become Public?
# By
# fdaudens
# •
# 3 days ago
# •
# 10
# AI Policy @🤗: Response to the 2025 National AI R&D Strategic Plan
# By
# evijit
# and 2 others
# •
# 7 days ago
# •
# 12
# Daily Robotics June #1 - SmolVLA discovery and thoughts
# By
# Beegbrain
# •
# 6 days ago
# •
# 9
# DeepSeek-R1 Dissection: Understanding PPO & GRPO Without Any Prior Reinforcement Learning Knowledge
# By
# NormalUhr
# •
# Feb 7
# •
# 150
# Fine-tune Llama 3.1 Ultra-Efficiently with Unsloth
# By
# mlabonne
# •
# Jul 29, 2024
# •
# 330
# 🦸🏻#14: What Is MCP, and Why Is Everyone – Suddenly!– Talking About It?
# By
# Kseniase
# •
# Mar 17
# •
# 284
# Google Opensources Deep Research Agents using Gemini 2.5 & LangGraph, Let's Take a Look
# By
# lynn-mikami
# •
# 6 days ago
# •
# 6
# Uncensor any LLM with abliteration
# By
# mlabonne
# •
# Jun 13, 2024
# •
# 606
# The Large Language Model Course
# By
# mlabonne
# •
# Jan 16
# •
# 187
# Bigger isn't always better: how to choose the most efficient model for context-specific tasks 🌱🧑🏼‍💻
# By
# sasha
# •
# 12 days ago
# •
# 20
# System Prompt Learning: Teaching LLMs to Learn Problem-Solving Strategies from Experience
# By
# codelion
# •
# 8 days ago
# •
# 10
# Code a simple RAG from scratch
# By
# ngxson
# •
# Oct 29, 2024
# •
# 89
# Fine-Tuning Your First Large Language Model (LLM) with PyTorch and Hugging Face
# By
# dvgodoy
# •
# Feb 11
# •
# 41
# Introduction to State Space Models (SSM)
# By
# lbourdois
# •
# Jul 19, 2024
# •
# 142
# KV Cache from scratch in nanoVLM
# By
# ariG23498
# June 4, 2025
# •
# 59
# SmolVLA: Efficient Vision-Language-Action Model trained on Lerobot Community Data
# By
# danaaubakirova
# June 3, 2025
# •
# 107
# No GPU left behind: Unlocking Efficiency with Co-located vLLM in TRL
# By
# toslali-ibm
# June 3, 2025
# guest
# •
# 39
# CodeAgents + Structure: A Better Way to Execute Actions
# By
# akseljoonas
# May 28, 2025
# •
# 50
# 🐯 Liger GRPO meets TRL
# By
# shisahni
# May 25, 2025
# guest
# •
# 36
# Dell Enterprise Hub is all you need to build AI on premises
# By
# jeffboudier
# May 23, 2025
# •
# 18
# Tiny Agents in Python: a MCP-powered agent in ~70 lines of code
# By
# celinah
# May 23, 2025
# •
# 122
# Exploring Quantization Backends in Diffusers
# By
# derekl35
# May 21, 2025
# •
# 33
# nanoVLM: The simplest repository to train your VLM in pure PyTorch
# By
# ariG23498
# May 21, 2025
# •
# 144
# Microsoft and Hugging Face expand collaboration
# By
# jeffboudier
# May 19, 2025
# •
# 21
# The Transformers Library: standardizing model definitions
# By
# lysandre
# May 15, 2025
# •
# 112
# Improving Hugging Face Model Access for Kaggle Users
# By
# roseberryv
# May 14, 2025
# •
# 28
# Blazingly fast whisper transcriptions with Inference Endpoints
# By
# mfuntowicz
# May 13, 2025
# •
# 68
# Vision Language Models (Better, Faster, Stronger)
# By
# merve
# May 12, 2025
# •
# 426
# Previous
# 1
# 2
# 3
# ...
# 42
# Next
# Community Articles
# Sort:
# 		Trending
# Holo1: New family of GUI automation VLMs powering GUI agent Surfer-H
# By
# Hcompany
# and 1 other
# •
# 6 days ago
# •
# 61
# The Common Pile v0.1
# By
# stellaathena
# and 2 others
# •
# 3 days ago
# •
# 25
# Explore, Build, and Innovate AI Reasoning with NVIDIA’s Open Models and Recipes
# By
# nvidia
# and 2 others
# •
# 5 days ago
# •
# 19
# *Context Is Gold to Find the Gold Passage*:  Evaluating and Training Contextual Document Embeddings
# By
# manu
# and 1 other
# •
# 7 days ago
# •
# 23
# Announcing the Common Pile and Comma v0.1
# By
# common-pile
# •
# 3 days ago
# •
# 13
# xLSTM-based time series model TiRex  significantly outperforms competing models in forecasting accuracy
# By
# BobWue
# •
# 5 days ago
# •
# 12
# What if Your AI Conversations Become Public?
# By
# fdaudens
# •
# 3 days ago
# •
# 10
# AI Policy @🤗: Response to the 2025 National AI R&D Strategic Plan
# By
# evijit
# and 2 others
# •
# 7 days ago
# •
# 12
# Daily Robotics June #1 - SmolVLA discovery and thoughts
# By
# Beegbrain
# •
# 6 days ago
# •
# 9
# DeepSeek-R1 Dissection: Understanding PPO & GRPO Without Any Prior Reinforcement Learning Knowledge
# By
# NormalUhr
# •
# Feb 7
# •
# 150
# Fine-tune Llama 3.1 Ultra-Efficiently with Unsloth
# By
# mlabonne
# •
# Jul 29, 2024
# •
# 330
# 🦸🏻#14: What Is MCP, and Why Is Everyone – Suddenly!– Talking About It?
# By
# Kseniase
# •
# Mar 17
# •
# 284
# Google Opensources Deep Research Agents using Gemini 2.5 & LangGraph, Let's Take a Look
# By
# lynn-mikami
# •
# 6 days ago
# •
# 6
# Uncensor any LLM with abliteration
# By
# mlabonne
# •
# Jun 13, 2024
# •
# 606
# The Large Language Model Course
# By
# mlabonne
# •
# Jan 16
# •
# 187
# Bigger isn't always better: how to choose the most efficient model for context-specific tasks 🌱🧑🏼‍💻
# By
# sasha
# •
# 12 days ago
# •
# 20
# System Prompt Learning: Teaching LLMs to Learn Problem-Solving Strategies from Experience
# By
# codelion
# •
# 8 days ago
# •
# 10
# Code a simple RAG from scratch
# By
# ngxson
# •
# Oct 29, 2024
# •
# 89
# Fine-Tuning Your First Large Language Model (LLM) with PyTorch and Hugging Face
# By
# dvgodoy
# •
# Feb 11
# •
# 41
# Introduction to State Space Models (SSM)
# By
# lbourdois
# •
# Jul 19, 2024
# •
# 142
# View all
# System theme
# Company
# TOS
# Privacy
# About
# Jobs
# Website
# Models
# Datasets
# Spaces
# Pricing
# Docs
#
#
#
# community forum
# Webpage Title:
# Hugging Face Forums - Hugging Face Community Discussion
# Webpage Contents:
# Hugging Face Forums
# Topic
# Replies
# Views
# Activity
# 404 Page Not Found when accessing the "Multiple Choice Quiz" in the "Exam Time!" section of the LLM Course (Section 11: Fine-Tune Large Language Models)
# Course
# 2
# 10
# June 9, 2025
# LevelBot can't see my Discord user ID
# Beginners
# 4
# 9
# June 9, 2025
# Error while initializing ZeroGPU
# Models
# 3
# 10
# June 9, 2025
# Fine tuning gpt-neo 2.7B with Lora on GSM8K - improve performance
# Beginners
# 1
# 8
# June 9, 2025
# Using dataset for classifier with mutiple categories
# Beginners
# 3
# 9
# June 9, 2025
# Ajay Hinduja Geneva : How Can I Integrate a Mobile App with My Travel Website?
# Beginners
# 1
# 8
# June 9, 2025
# Linux. Transfer ISOs
# Beginners
# 2
# 8
# June 9, 2025
# NotImplementedError when loading dataset with Streamlit
# 🤗Datasets
# 7
# 9784
# June 9, 2025
# Do AI apps need search engine optimization?
# Beginners
# 2
# 8
# June 9, 2025
# How was self.loss_function implemented
# 🤗Transformers
# 3
# 7
# June 9, 2025
# Efficient batch inference using stacked past_key_values for multiple continuation candidates
# Models
# 0
# 8
# June 9, 2025
# Not been able to add POST api method using Flask
# Beginners
# 2
# 11
# June 9, 2025
# Tribit: A 36-Bit Symbolic Compression System for Tokenization, Reasoning, and Command Encoding
# 🤗Datasets
# 2
# 6
# June 9, 2025
# Introducing Tribit – A Symbolic Compression System for Language, Code, and Execution
# Research
# 2
# 9
# June 9, 2025
# Error handling POST request to Flask API route which uses pandas to read payload
# Beginners
# 0
# 5
# June 9, 2025
# It is your own script/code, surely it will work, right?
# Beginners
# 2
# 22
# June 8, 2025
# Problem Summary: Hugging Face Space Running, but Line Webhook Verification Fails with No Logs
# Beginners
# 1
# 14
# June 8, 2025
# Simplifying Hugging Face Spaces API calls in Flutter using hugging_face_chat_gradio package
# Intermediate
# 4
# 28
# June 8, 2025
# HF auto train dataset load_metric error
# Beginners
# 33
# 75
# June 5, 2025
# A professionally translating LLM?
# Beginners
# 1
# 12
# June 9, 2025
# Can I ask a question if I have a good idea but can't write programs?
# Beginners
# 41
# 253
# June 3, 2025
# My Thoughts on Ollama (for a Serious Project) 🚀
# Beginners
# 2
# 46
# June 7, 2025
# Setfit trainer doesn't appear to be changing any weights
# Beginners
# 1
# 8
# June 8, 2025
# Segmant Anything Model (SAM) ValueError: Invalid image type
# Models
# 1
# 7
# June 8, 2025
# Account Issue: New API Tokens all fail with 401 Unauthorized Error
# Beginners
# 1
# 9
# June 8, 2025
# How to implement bind_tools to custom LLM from huggingface pipeline(Llama-3) for a custom agent
# Intermediate
# 3
# 1221
# June 9, 2025
# Can't submit my paper to daily papers
# 🤗Hub
# 2
# 39
# June 9, 2025
# AI implementation with raspberry pi mini
# Beginners
# 1
# 18
# June 7, 2025
# Inference API stopped working
# Inference Endpoints on the Hub
# 50
# 2901
# June 8, 2025
# Do we need a new programming language optimized for AI to write code?
# Intermediate
# 3
# 43
# June 6, 2025
# next page →
# Home
# Categories
# Guidelines
# Terms of Service
# Privacy Policy
# Powered by
# Discourse
# , best viewed with JavaScript enabled
#
#
#
# GitHub page
# Webpage Title:
# Hugging Face · GitHub
# Webpage Contents:
# Skip to content
# Navigation Menu
# Toggle navigation
# Sign in
# Appearance settings
# huggingface
# Product
# GitHub Copilot
# Write better code with AI
# GitHub Models
# New
# Manage and compare prompts
# GitHub Advanced Security
# Find and fix vulnerabilities
# Actions
# Automate any workflow
# Codespaces
# Instant dev environments
# Issues
# Plan and track work
# Code Review
# Manage code changes
# Discussions
# Collaborate outside of code
# Code Search
# Find more, search less
# Explore
# Why GitHub
# All features
# Documentation
# GitHub Skills
# Blog
# Solutions
# By company size
# Enterprises
# Small and medium teams
# Startups
# Nonprofits
# By use case
# DevSecOps
# DevOps
# CI/CD
# View all use cases
# By industry
# Healthcare
# Financial services
# Manufacturing
# Government
# View all industries
# View all solutions
# Resources
# Topics
# AI
# DevOps
# Security
# Software Development
# View all
# Explore
# Learning Pathways
# Events & Webinars
# Ebooks & Whitepapers
# Customer Stories
# Partners
# Executive Insights
# Open Source
# GitHub Sponsors
# Fund open source developers
# The ReadME Project
# GitHub community articles
# Repositories
# Topics
# Trending
# Collections
# Enterprise
# Enterprise platform
# AI-powered developer platform
# Available add-ons
# GitHub Advanced Security
# Enterprise-grade security features
# Copilot for business
# Enterprise-grade AI features
# Premium Support
# Enterprise-grade 24/7 support
# Pricing
# Search or jump to...
# Search code, repositories, users, issues, pull requests...
# Search
# Clear
# Search syntax tips
# Provide feedback
# We read every piece of feedback, and take your input very seriously.
# Include my email address so I can be contacted
# Cancel
# Submit feedback
# Saved searches
# Use saved searches to filter your results more quickly
# Cancel
# Create saved search
# Sign in
# Sign up
# Appearance settings
# Resetting focus
# You signed in with another tab or window.
# Reload
# to refresh your session.
# You signed out in another tab or window.
# Reload
# to refresh your session.
# You switched accounts on another tab or window.
# Reload
# to refresh your session.
# Dismiss alert
# Hugging Face
# The AI community building the future.
# Verified
# We've verified that the organization
# huggingface
# controls the domain:
# huggingface.co
# Learn more about verified organizations
# 50k
# followers
# NYC + Paris
# https://huggingface.co/
# X
# @huggingface
# Overview
# Repositories
# Projects
# Packages
# People
# Sponsoring
# 0
# More
# Overview
# Repositories
# Projects
# Packages
# People
# Sponsoring
# Pinned
# Loading
# transformers
# transformers
# Public
# 🤗 Transformers: State-of-the-art Machine Learning for Pytorch, TensorFlow, and JAX.
# Python
# 145k
# 29.3k
# diffusers
# diffusers
# Public
# 🤗 Diffusers: State-of-the-art diffusion models for image, video, and audio generation in PyTorch and FLAX.
# Python
# 29.3k
# 6k
# datasets
# datasets
# Public
# 🤗 The largest hub of ready-to-use datasets for ML models with fast, easy-to-use and efficient data manipulation tools
# Python
# 20.3k
# 2.8k
# peft
# peft
# Public
# 🤗 PEFT: State-of-the-art Parameter-Efficient Fine-Tuning.
# Python
# 18.7k
# 1.9k
# accelerate
# accelerate
# Public
# 🚀 A simple way to launch, train, and use PyTorch models on almost any device and distributed configuration, automatic mixed precision (including fp8), and easy-to-configure FSDP and DeepSpeed support
# Python
# 8.8k
# 1.1k
# optimum
# optimum
# Public
# 🚀 Accelerate inference and training of 🤗 Transformers, Diffusers, TIMM and Sentence Transformers with easy to use hardware optimization tools
# Python
# 2.9k
# 544
# Repositories
# Loading
# Type
# Select type
# Forks
# Archived
# Mirrors
# Templates
# Language
# Select language
# All
# C
# C#
# C++
# Cuda
# Dockerfile
# Go
# Handlebars
# HTML
# Java
# JavaScript
# Jupyter Notebook
# Kotlin
# Lua
# MDX
# Mustache
# Nix
# Python
# Rust
# Shell
# Smarty
# Svelte
# Swift
# TypeScript
# Sort
# Select order
# Last updated
# Name
# Stars
# Showing 10 of 320 repositories
# transformers
# Public
# 🤗 Transformers: State-of-the-art Machine Learning for Pytorch, TensorFlow, and JAX.
# Uh oh!
# There was an error while loading.
# Please reload this page
# .
# huggingface/transformers’s past year of commit activity
# Python
# 145,364
# Apache-2.0
# 29,279
# 1,050
# (2 issues need help)
# 774
# Updated
# Jun 9, 2025
# chat-ui
# Public
# Open source codebase powering the HuggingChat app
# Uh oh!
# There was an error while loading.
# Please reload this page
# .
# huggingface/chat-ui’s past year of commit activity
# TypeScript
# 8,823
# Apache-2.0
# 1,331
# 315
# (1 issue needs help)
# 15
# Updated
# Jun 9, 2025
# diffusers
# Public
# 🤗 Diffusers: State-of-the-art diffusion models for image, video, and audio generation in PyTorch and FLAX.
# huggingface/diffusers’s past year of commit activity
# Python
# 29,297
# Apache-2.0
# 6,012
# 500
# (12 issues need help)
# 195
# Updated
# Jun 9, 2025
# trl
# Public
# Train transformer language models with reinforcement learning.
# huggingface/trl’s past year of commit activity
# Python
# 14,096
# Apache-2.0
# 1,949
# 397
# 80
# Updated
# Jun 9, 2025
# accelerate
# Public
# 🚀 A simple way to launch, train, and use PyTorch models on almost any device and distributed configuration, automatic mixed precision (including fp8), and easy-to-configure FSDP and DeepSpeed support
# huggingface/accelerate’s past year of commit activity
# Python
# 8,814
# Apache-2.0
# 1,123
# 82
# (4 issues need help)
# 20
# Updated
# Jun 9, 2025
# hub-docs
# Public
# Docs of the Hugging Face Hub
# huggingface/hub-docs’s past year of commit activity
# Handlebars
# 396
# Apache-2.0
# 316
# 105
# 25
# Updated
# Jun 9, 2025
# xet-core
# Public
# xet client tech, used in huggingface_hub
# Uh oh!
# There was an error while loading.
# Please reload this page
# .
# huggingface/xet-core’s past year of commit activity
# Rust
# 112
# Apache-2.0
# 13
# 5
# 8
# Updated
# Jun 9, 2025
# lerobot
# Public
# 🤗 LeRobot: Making AI for Robotics more accessible with end-to-end learning
# Uh oh!
# There was an error while loading.
# Please reload this page
# .
# huggingface/lerobot’s past year of commit activity
# Python
# 14,254
# Apache-2.0
# 1,788
# 239
# 149
# Updated
# Jun 9, 2025
# dataset-viewer
# Public
# Backend that powers the dataset viewer on Hugging Face dataset pages through a public API.
# huggingface/dataset-viewer’s past year of commit activity
# Python
# 756
# Apache-2.0
# 90
# 133
# (6 issues need help)
# 10
# Updated
# Jun 9, 2025
# optimum-habana
# Public
# Easy and lightning fast training of 🤗 Transformers on Habana Gaudi processor (HPU)
# huggingface/optimum-habana’s past year of commit activity
# Python
# 188
# Apache-2.0
# 258
# 17
# (1 issue needs help)
# 42
# Updated
# Jun 9, 2025
# View all repositories
# People
# View all
# Top languages
# Python
# Jupyter Notebook
# Rust
# TypeScript
# JavaScript
# Most used topics
# Loading…
# Uh oh!
# There was an error while loading.
# Please reload this page
# .
# Footer
# © 2025 GitHub, Inc.
# Footer navigation
# Terms
# Privacy
# Security
# Status
# Docs
# Contact
# Manage cookies
# Do not share my personal information
# You can’t perform that action at this time.
#
#
#
# Twitter page
# Webpage Title:
# No title found
# Webpage Contents:
# JavaScript is not available.
# We’ve detected that JavaScript is disabled in this browser. Please enable JavaScript or switch to a supported browser to continue using x.com. You can see a list of supported browsers in our Help Center.
# Help Center
# Terms of Service
# Privacy Policy
# Cookie Policy
# Imprint
# Ads info
# © 2025 X Corp.
# Something went wrong, but don’t fret — let’s give it another shot.
# Try again
# Some privacy related extensions may cause issues on x.com. Please disable them and try again.
#
#
#
# LinkedIn page
# Webpage Title:
# Hugging Face | LinkedIn
# Webpage Contents:
# Skip to main content
# LinkedIn
# Articles
# People
# Learning
# Jobs
# Games
# Get the app
# Join now
# Sign in
# Hugging Face
# Software Development
# The AI community building the future.
# See jobs
# Follow
# View all 548 employees
# Report this company
# About us
# The AI community building the future.
# Website
# https://huggingface.co
# External link for Hugging Face
# Industry
# Software Development
# Company size
# 51-200 employees
# Type
# Privately Held
# Founded
# 2016
# Specialties
# machine learning, natural language processing, and deep learning
# Products
# Hugging Face
# Hugging Face
# Natural Language Processing (NLP) Software
# We’re on a journey to solve and democratize artificial intelligence through natural language.
# Locations
# Primary
# Get directions
# Paris, FR
# Get directions
# Employees at Hugging Face
# Ludovic Huraux
# Rajat Arya
# Tech Lead & Software Engineer @ HF | prev: co-founder XetHub, Apple, Turi, AWS, Microsoft
# Jeff Boudier
# Product + Growth at Hugging Face
# Terrence Rohan
# Seed Investor
# See all employees
# Updates
# Hugging Face
# 984,401 followers
# 2h
# Report this post
# 🦾🦾🦾
# Clem Delangue 🤗
# Clem Delangue 🤗 is an Influencer
# Co-founder & CEO at Hugging Face
# 5h
# This weekend, thousands will learn, build, train & play with AI robots simultaneously from 100 different cities worldwide in what is turning out to be the biggest robotics hackathon ever organized, thanks to LeRobot.
#
# Let's make history!
# 40
# Like
# Comment
# Share
# Hugging Face
# reposted this
# Daniel van Strien
# Machine Learning Librarian at 🤗
# 9h
# Report this post
# I built an MCP server for the Hugging Face ecosystem 🚀
#
# Inspired by
# Hugging Face
# 's official MCP server, I've developed a complementary tool that exposes my semantic search API to enhance discovery across the HF platform.
#
# Key capabilities:
#
# - AI-powered semantic search for models and datasets
# - Parameter count analysis via safetensors metadata
# - Trending content discovery
# - Find similar models/datasets functionality
# - 11 tools total for enhanced ecosystem navigation
#
# The semantic search goes beyond simple keyword matching, understanding context and relationships between different models and datasets.
#
# Example query: "Find around 10 reasoning Hugging Face datasets published in 2025 focusing on topics other than maths and science. Show a link and a short summary for each dataset." (results in video!)
# https://lnkd.in/eFi8PS87
# …more
# 112
# 8 Comments
# Like
# Comment
# Share
# Hugging Face
# reposted this
# Gradio
# 65,625 followers
# 1d
# Report this post
# Keep it up folks 🔥
# …more
# 59
# 3 Comments
# Like
# Comment
# Share
# Hugging Face
# reposted this
# Gradio
# 65,625 followers
# 2d
# Report this post
# 🎉 HACKATHON UPDATE: Extended Deadline by 2 Days Due to Incredible Response!
# We're thrilled to announce a 2-day extension for the Gradio Agents & MCP Hackathon due to overwhelming community participation!
#
# NEW DEADLINE: June 10, 2025 (Tuesday) UTC EOD
#
# 💪 The response has been phenomenal:
# 4100+ developers actively building
# 200+ projects in development
# $1M+ in API credits being utilized
# $16,500 in cash prizes across 3 tracks
#
# This extension gives our amazing community more time to polish their AI agents, MCP servers, and custom Gradio components.
#
# Three Competition Tracks:
# 🔧 MCP Server Development
# 🛠️ Custom Gradio Components
# 🤖 Agentic AI Demonstrations
#
# Whether you're building a supercool AI Agents or sturdy MCP Servers, there's still time to participate and win.
#
# Join the Huggingface Organization page:
# https://lnkd.in/g7yp9HKG
# Discord:
# https://lnkd.in/gnxTPZvB
# Who's ready to WIN? 💯
# 40
# Like
# Comment
# Share
# Hugging Face
# reposted this
# Julien Chaumond
# CTO at Hugging Face
# 3d
# Report this post
# Today is a big day, we're introducing the first version of the HF MCP server 🔥
#
# Connect to the Hub APIs programmatically from your LLM, directly from
# - VSCode,
# - Cursor,
# - Claude Desktop,
# - or any other MCP-powered app
#
# We expose:
# 1️⃣ a curated set of built-in tools like Spaces and Papers Semantic Search, Model and Dataset exploration, etc
# 2️⃣ even cooler, we expose a dynamic list of all MCP-compatible
# Gradio
# apps hosted on Spaces 🤯
#
# And... the server is open source! Built by
# Shaun Smith
# and the
# Hugging Face
# team 💓
#
# Link to get started in the first comment ⤵️
# 2,838
# 103 Comments
# Like
# Comment
# Share
# Hugging Face
# reposted this
# Gradio
# 65,625 followers
# 3d
# Edited
# Report this post
# Finally, it is here!!! > Access the
# Hugging Face
# Hub through your LLMs
#
# Checkout our changelog for more:
# https://lnkd.in/gT-UX79R
# 🤯 Join the Biggest ever Agents-MCP Hackathon here and win Cash prizes ranging from $500 to $5000:
# https://lnkd.in/g7yp9HKG
# 48
# Like
# Comment
# Share
# Hugging Face
# reposted this
# Amir Mahla
# Building agents @ Hugging Face 🤗
# 3d
# Edited
# Report this post
# 🚀 Excited to announce we're releasing ScreenSuite - the most comprehensive evaluation suite for GUI Agents!
#
# GUI Agents have exploded since Claude Computer Use launched, but evaluating them has been a nightmare... until now.
#
# What makes ScreenSuite special?
#
# ✅ Brings together 13 different benchmarks from state-of-the-art research
# ✅ Vision-only evaluation (no cheating with DOM trees or APIs)
# ✅ Ubuntu & Android environments Dockerized for strong reproducibility
# ✅ Extensive test coverage across mobile, desktop, and web
#
# What's inside:
#
# 📱 Mobile Android task scenarios across diverse apps
# 🖥️ Complex desktop task navigation
# 🌐 Comprehensive web interaction scenarios
# 🤖 Multi-step agentic capabilities across all platforms
#
# We tested leading VLMs including GPT-4o, QwenVL, UI-TARS, … . The results? Even top models struggle with multi-step GUI tasks - highlighting just how challenging this space is.
#
# Why this matters: GUI agents represent the future of human-computer interaction. They need to navigate interfaces just like we do and even better - through vision alone, not privileged access to code.
#
# Ready to benchmark your GUI agent? ScreenSuite makes it simple.
#
# 📖 Read the full blog post:
# https://lnkd.in/gC5CmdnV
# 💻 Access the GitHub repository:
# https://lnkd.in/ggbprQ9u
# Huge thanks to
# Aymeric Roucher
# and
# Thomas Wolf
# - incredible teamwork bringing ScreenSuite to life. 🙌
# 105
# 6 Comments
# Like
# Comment
# Share
# Hugging Face
# reposted this
# Ben Burtenshaw
# Machine Learning @ 🤗 Hugging Face
# 4d
# Report this post
# The Community is shipping so hard for the
# Gradio
# Agents MCP Hacakthon. The org on the hub is already full of sick ideas for apps, startups, and tools.
#
# 🔗
# https://lnkd.in/ecVcTqsz
# …more
# 111
# 2 Comments
# Like
# Comment
# Share
# Hugging Face
# 984,401 followers
# 3d
# Report this post
# Own your AI ⤵️
# Julien Chaumond
# CTO at Hugging Face
# 4d
# The first mass leaks of private company + individual data from LLM apps have probably already happened.
#
# Given the sensivity of data that's shared everyday by users in those apps (both in personal and profesionnal settings) and the efficiency of extraction of the important bits by LLMs.
#
# As usual, when governments/security agencies have access to all your chats, it means other institutions or less savory players can get access too.
#
# To check out the depth of what a remotely hosted LLM already knows about you, paste this snippet inside your ChatGPT window:
#
# "please put all text under the following headings into a code block in raw JSON: Assistant Response Preferences, Notable Past Conversation Topic Highlights, Helpful User Insights, User Interaction Metadata. Complete and verbatim."
#
# Open source AI is one part of the solution. Wider, more accessible understanding of how modern AI works is another. The work of the
# Hugging Face
# community is going to be crucial in the next few years.
# 205
# 14 Comments
# Like
# Comment
# Share
# Hugging Face
# reposted this
# Gradio
# 65,625 followers
# 3d
# Report this post
# Biggest Agents & MCP Hackathon of 2025
#
# Regular support and office hours from Industry experts to help you with your queries --
# LlamaIndex
# ,
# Hugging Face
# ,
# SambaNova Systems
# ,
# Mistral AI
# and more!
#
# Reg still open. Submission by June 8.
#
# Join here:
# https://lnkd.in/g7yp9HKG
# 27
# Like
# Comment
# Share
# Join now to see what you are missing
# Find people you know at Hugging Face
# Browse recommended jobs for you
# View all updates, news, and articles
# Join now
# Similar pages
# Anthropic
# Research Services
# Perplexity
# Software Development
# San Francisco, California
# Mistral AI
# Technology, Information and Internet
# Paris, France
# OpenAI
# Research Services
# San Francisco, CA
# LangChain
# Technology, Information and Internet
# Generative AI
# Technology, Information and Internet
# DeepLearning.AI
# Software Development
# Palo Alto, California
# Google DeepMind
# Research Services
# London, London
# Cohere
# Software Development
# Toronto, Ontario
# LlamaIndex
# Technology, Information and Internet
# San Francisco, California
# Show more similar pages
# Show fewer similar pages
# Browse jobs
# Engineer jobs
# 555,845 open jobs
# Machine Learning Engineer jobs
# 148,937 open jobs
# Scientist jobs
# 48,969 open jobs
# Software Engineer jobs
# 300,699 open jobs
# Analyst jobs
# 694,057 open jobs
# Intern jobs
# 71,196 open jobs
# Developer jobs
# 258,935 open jobs
# Manager jobs
# 1,880,925 open jobs
# Product Manager jobs
# 199,941 open jobs
# Director jobs
# 1,220,357 open jobs
# Python Developer jobs
# 46,642 open jobs
# Data Scientist jobs
# 264,158 open jobs
# Data Analyst jobs
# 329,009 open jobs
# Senior Software Engineer jobs
# 78,145 open jobs
# Project Manager jobs
# 253,048 open jobs
# Researcher jobs
# 195,654 open jobs
# Associate jobs
# 1,091,945 open jobs
# Data Engineer jobs
# 192,126 open jobs
# Vice President jobs
# 235,270 open jobs
# Specialist jobs
# 768,666 open jobs
# Show more jobs like this
# Show fewer jobs like this
# Funding
# Hugging Face
# 8 total rounds
# Last Round
# Series unknown
# Sep 1, 2024
# External Crunchbase Link for last round of funding
# See more info on
# crunchbase
# More searches
# More searches
# Engineer jobs
# Scientist jobs
# Machine Learning Engineer jobs
# Software Engineer jobs
# Intern jobs
# Developer jobs
# Analyst jobs
# Manager jobs
# Senior Software Engineer jobs
# Data Scientist jobs
# Researcher jobs
# Product Manager jobs
# Director jobs
# Associate jobs
# Intelligence Specialist jobs
# Data Analyst jobs
# Data Science Specialist jobs
# Python Developer jobs
# Quantitative Analyst jobs
# Project Manager jobs
# Account Executive jobs
# Specialist jobs
# Data Engineer jobs
# Designer jobs
# Quantitative Researcher jobs
# Consultant jobs
# Solutions Architect jobs
# Vice President jobs
# User Experience Designer jobs
# Head jobs
# Full Stack Engineer jobs
# Engineering Manager jobs
# Software Engineer Intern jobs
# Junior Software Engineer jobs
# Software Intern jobs
# Product Designer jobs
# Solutions Engineer jobs
# Staff Software Engineer jobs
# Program Manager jobs
# Senior Scientist jobs
# Writer jobs
# Research Intern jobs
# Senior Product Manager jobs
# Summer Intern jobs
# Account Manager jobs
# Recruiter jobs
# Lead jobs
# Research Engineer jobs
# Computer Science Intern jobs
# Platform Engineer jobs
# Junior Developer jobs
# Android Developer jobs
# User Experience Researcher jobs
# Java Software Engineer jobs
# Site Reliability Engineer jobs
# Graduate jobs
# Software Engineering Manager jobs
# Representative jobs
# Business Development Specialist jobs
# Computer Engineer jobs
# LinkedIn
# © 2025
# About
# Accessibility
# User Agreement
# Privacy Policy
# Your California Privacy Choices
# Cookie Policy
# Copyright Policy
# Brand Policy
# Guest Controls
# Community Guidelines
# العربية (Arabic)
# বাংলা (Bangla)
# Čeština (Czech)
# Dansk (Danish)
# Deutsch (German)
# Ελληνικά (Greek)
# English (English)
# Español (Spanish)
# فارسی (Persian)
# Suomi (Finnish)
# Français (French)
# हिंदी (Hindi)
# Magyar (Hungarian)
# Bahasa Indonesia (Indonesian)
# Italiano (Italian)
# עברית (Hebrew)
# 日本語 (Japanese)
# 한국어 (Korean)
# मराठी (Marathi)
# Bahasa Malaysia (Malay)
# Nederlands (Dutch)
# Norsk (Norwegian)
# ਪੰਜਾਬੀ (Punjabi)
# Polski (Polish)
# Português (Portuguese)
# Română (Romanian)
# Русский (Russian)
# Svenska (Swedish)
# తెలుగు (Telugu)
# ภาษาไทย (Thai)
# Tagalog (Tagalog)
# Türkçe (Turkish)
# Українська (Ukrainian)
# Tiếng Việt (Vietnamese)
# 简体中文 (Chinese (Simplified))
# 正體中文 (Chinese (Traditional))
# Language
# Agree & Join LinkedIn
# By clicking Continue to join or sign in, you agree to LinkedIn’s
# User Agreement
# ,
# Privacy Policy
# , and
# Cookie Policy
# .
# Sign in to see who you already know at Hugging Face
# Sign in
# Welcome back
# Email or phone
# Password
# Show
# Forgot password?
# Sign in
# or
# By clicking Continue to join or sign in, you agree to LinkedIn’s
# User Agreement
# ,
# Privacy Policy
# , and
# Cookie Policy
# .
# New to LinkedIn?
# Join now
# or
# New to LinkedIn?
# Join now
# By clicking Continue to join or sign in, you agree to LinkedIn’s
# User Agreement
# ,
# Privacy Policy
# , and
# Cookie Policy
# .
# LinkedIn
# LinkedIn is better on the app
# Don’t have the app? Get it in the Microsoft Store.
# Open the app

# %%
# system_prompt = "You are an assistant that analyzes the contents of several relevant pages from a company website \
# and creates a short brochure about the company for prospective customers, investors and recruits. Respond in markdown.\
# Include details of company culture, customers and careers/jobs if you have the information."

# Or uncomment the lines below for a more humorous brochure - this demonstrates how easy it is to incorporate 'tone':

system_prompt = "You are an assistant that analyzes the contents of several relevant pages from a company website \
and creates a short humorous, entertaining, jokey brochure about the company for prospective customers, investors and recruits. Respond in markdown.\
Include details of company culture, customers and careers/jobs if you have the information."

# %%
def get_brochure_user_prompt(company_name, url):
    user_prompt = f"You are looking at a company called: {company_name}\n"
    user_prompt += f"Here are the contents of its landing page and other relevant pages; use this information to build a short brochure of the company in markdown.\n"
    user_prompt += get_all_details(url)
    user_prompt = user_prompt[:5_000] # Truncate if more than 5,000 characters
    return user_prompt

# %%
get_brochure_user_prompt("HuggingFace", "https://huggingface.co")
# Out:
# Found links: {'links': [{'type': 'about page', 'url': 'https://huggingface.co/huggingface'}, {'type': 'careers page', 'url': 'https://apply.workable.com/huggingface/'}, {'type': 'enterprise page', 'url': 'https://huggingface.co/enterprise'}, {'type': 'pricing page', 'url': 'https://huggingface.co/pricing'}, {'type': 'blog page', 'url': 'https://huggingface.co/blog'}, {'type': 'documentation page', 'url': 'https://huggingface.co/docs'}]}
# 'You are looking at a company called: HuggingFace\nHere are the contents of its landing page and other relevant pages; use this information to build a short brochure of the company in markdown.\nLanding page:\nWebpage Title:\nHugging Face – The AI community building the future.\nWebpage Contents:\nHugging Face\nModels\nDatasets\nSpaces\nCommunity\nDocs\nEnterprise\nPricing\nLog In\nSign Up\nThe AI community building the future.\nThe platform where the machine learning community collaborates on models, datasets, and applications.\nExplore AI Apps\nor\nBrowse 1M+ models\nTrending on\nthis week\nModels\ndeepseek-ai/DeepSeek-R1-0528\nUpdated\n11 days ago\n•\n97.1k\n•\n1.88k\ngoogle/gemma-3n-E4B-it-litert-preview\nUpdated\n14 days ago\n•\n1.05k\nQwen/Qwen3-Embedding-0.6B-GGUF\nUpdated\nabout 14 hours ago\n•\n8.45k\n•\n257\nResembleAI/chatterbox\nUpdated\n10 days ago\n•\n729\nfishaudio/openaudio-s1-mini\nUpdated\n7 days ago\n•\n1.25k\n•\n181\nBrowse 1M+ models\nSpaces\nRunning\non\nZero\n922\n922\nChatterbox TTS\n🍿\nExpressive Zeroshot TTS\nRunning\n7.83k\n7.83k\nDeepSite\n🐳\nGenerate any application with DeepSeek\nRunning\non\nZero\n573\n573\nWan2.1 Fast\n🎥\nTurn static images into animated videos\nRunning\non\nZero\n236\n236\nChain-of-Zoom\n🚀\nExtreme Super-Resolution via Scale Autoregression\nRunning\n476\n476\nRealistic Text To Speech Unlimited\n🔥\nFree Text-To-Speech generator with Emotion control (OpenAI)\nBrowse 400k+ applications\nDatasets\nfka/awesome-chatgpt-prompts\nUpdated\nJan 6\n•\n20.9k\n•\n7.89k\nopen-thoughts/OpenThoughts3-1.2M\nUpdated\nabout 4 hours ago\n•\n3.7k\n•\n66\nyandex/yambda\nUpdated\n3 days ago\n•\n39.6k\n•\n153\nHcompany/WebClick\nUpdated\nabout 4 hours ago\n•\n3.56k\n•\n45\nopen-r1/Mixture-of-Thoughts\nUpdated\n14 days ago\n•\n30.1k\n•\n206\nBrowse 250k+ datasets\nThe Home of Machine Learning\nCreate, discover and collaborate on ML better.\nThe collaboration platform\nHost and collaborate on unlimited public models, datasets and applications.\nMove faster\nWith the HF Open source stack.\nExplore all modalities\nText, image, video, audio or even 3D.\nBuild your portfolio\nShare your work with the world and build your ML profile.\nSign Up\nAccelerate your ML\nWe provide paid Compute and Enterprise solutions.\nCompute\nDeploy on optimized\nInference Endpoints\nor update your\nSpaces applications\nto a GPU in a few clicks.\nView pricing\nStarting at $0.60/hour for GPU\nEnterprise\nGive your team the most advanced platform to build AI with enterprise-grade security, access controls and\n\t\t\tdedicated support.\nGetting started\nStarting at $20/user/month\nSingle Sign-On\nRegions\nPriority Support\nAudit Logs\nResource Groups\nPrivate Datasets Viewer\nMore than 50,000 organizations are using Hugging Face\nAi2\nEnterprise\nnon-profit\n•\n765 models\n•\n3.39k followers\nAI at Meta\nEnterprise\ncompany\n•\n2.15k models\n•\n6.35k followers\nAmazon\ncompany\n•\n20 models\n•\n3.22k followers\nGoogle\ncompany\n•\n997 models\n•\n16.2k followers\nIntel\ncompany\n•\n230 models\n•\n2.62k followers\nMicrosoft\ncompany\n•\n386 models\n•\n12.8k followers\nGrammarly\nEnterprise\ncompany\n•\n10 models\n•\n162 followers\nWriter\nEnterprise\ncompany\n•\n22 models\n•\n294 followers\nOur Open Source\nWe are building the foundation of ML tooling with the community.\nTransformers\n145,363\nState-of-the-art ML for PyTorch, TensorFlow, JAX\nDiffusers\n29,297\nState-of-the-art Diffusion models in PyTorch\nSafetensors\n3,298\nSafe way to store/distribute neural network weights\nHub Python Library\n2,675\nPython client to interact with the Hugging Face Hub\nTokenizers\n9,774\nFast tokenizers optimized for research & production\nTRL\n14,095\nTrain transformers LMs with reinforcement learning\nTransformers.js\n13,765\nState-of-the-art ML running directly in your browser\nsmolagents\n19,918\nSmol library to build great agents in Python\nPEFT\n18,712\nParameter-efficient finetuning for large language models\nDatasets\n20,257\nAccess & sh ...

# %%
def create_brochure(company_name, url):
    response = openai.chat.completions.create(
        model=MODEL,
        messages=[
            {"role": "system", "content": system_prompt},
            {"role": "user", "content": get_brochure_user_prompt(company_name, url)}
          ],
    )
    result = response.choices[0].message.content
    display(Markdown(result))

# %%
create_brochure("HuggingFace", "https://huggingface.co")
# Out:
# Found links: {'links': [{'type': 'about page', 'url': 'https://huggingface.co/huggingface'}, {'type': 'careers page', 'url': 'https://apply.workable.com/huggingface/'}, {'type': 'enterprise page', 'url': 'https://huggingface.co/enterprise'}, {'type': 'pricing page', 'url': 'https://huggingface.co/pricing'}, {'type': 'blog page', 'url': 'https://huggingface.co/blog'}, {'type': 'discussion forum', 'url': 'https://discuss.huggingface.co'}, {'type': 'GitHub page', 'url': 'https://github.com/huggingface'}, {'type': 'Twitter page', 'url': 'https://twitter.com/huggingface'}, {'type': 'LinkedIn page', 'url': 'https://www.linkedin.com/company/huggingface/'}]}
# # Hugging Face: The AI Community Shaping the Future
#
# Welcome to Hugging Face – where innovation in artificial intelligence meets community collaboration. Hugging Face is a leading platform tailored for machine learning enthusiasts, developers, researchers, and enterprises, fostering an environment that champions cooperation and exploration in the AI realm.
#
# ## Our Mission
# **Building the Future of AI**
# At Hugging Face, we believe in the power of collective intelligence. We strive to create a community-driven ecosystem where individuals and organizations collaborate on models, datasets, and applications, propelling the field of AI forward.
#
# ## Our Offerings
# - **Models**: Explore over **1 million models** tailored for various applications across text, image, audio, and more.
# - **Datasets**: Access a rich repository containing **250,000+ datasets**, empowering users to find the perfect resources for their machine learning projects.
# - **Spaces**: Run and share your applications seamlessly with our user-friendly platform designed for collaboration.
# - **Enterprise Solutions**: We offer robust enterprise-grade solutions with advanced security, support, and access controls, to cater to teams looking to innovate securely and efficiently.
#
# ### Trending Models
# 1. **DeepSeek-R1-0528** – 97.1k updates
# 2. **Gemma-3N-E4B** – 1.05k updates
# 3. **Qwen3-Embedding-0.6B** – 8.45k updates
#
# ### Notable Customers
# Join over **50,000 organizations** leveraging Hugging Face’s solutions, including:
# - **Meta**
# - **Google**
# - **Microsoft**
# - **Amazon**
# - **Intel**
# *These companies are harnessing the power of AI to drive their operations, develop innovative products, and augment their tech stacks.*
#
# ## Company Culture
# At Hugging Face, our diverse team is united by a shared passion for AI and a commitment to open collaboration. We value creativity and curiosity, encouraging our members to learn, grow, and contribute to the community. Our culture promotes openness and transparency, fostering an environment where everyone can share their ideas and research.
#
# ### Join Our Community
# We are always looking for passionate individuals to join our team! Explore exciting career opportunities at Hugging Face, where you can contribute to shaping the future of AI.
#
# - **Current Openings**: Visit our [Jobs Page](https://huggingface.co/jobs) for the latest roles and how to apply.
#
# [Explore Our Platform](https://huggingface.co)
# [Join Our Community](https://huggingface.co/community)
#
# Together, let’s build a smarter and more connected world through AI!

# %% [markdown]
# ## Finally - a minor improvement
#
# With a small adjustment, we can change this so that the results stream back from OpenAI,
# with the familiar typewriter animation

# %%
def stream_brochure(company_name, url):
    stream = openai.chat.completions.create(
        model=MODEL,
        messages=[
            {"role": "system", "content": system_prompt},
            {"role": "user", "content": get_brochure_user_prompt(company_name, url)}
          ],
        stream=True
    )
    
    response = ""
    display_handle = display(Markdown(""), display_id=True)
    for chunk in stream:
        response += chunk.choices[0].delta.content or ''
        response = response.replace("```","").replace("markdown", "")
        update_display(Markdown(response), display_id=display_handle.display_id)

# %%
stream_brochure("HuggingFace", "https://huggingface.co")
# Out:
# Found links: {'links': [{'type': 'about page', 'url': 'https://huggingface.co/huggingface'}, {'type': 'careers page', 'url': 'https://apply.workable.com/huggingface/'}, {'type': 'enterprise page', 'url': 'https://huggingface.co/enterprise'}, {'type': 'pricing page', 'url': 'https://huggingface.co/pricing'}, {'type': 'blog page', 'url': 'https://huggingface.co/blog'}, {'type': 'company page', 'url': 'https://www.linkedin.com/company/huggingface/'}]}
# # Hugging Face Brochure
#
# **The AI Community Building the Future**
#
# ---
#
# ## About Us
#
# Hugging Face is a pioneering platform at the forefront of artificial intelligence and machine learning, dedicated to fostering collaboration within the community. Our mission is to provide tools that streamline the process of creating, discovering, and collaborating on models, datasets, and applications, thereby accelerating advancements in the field of AI.
#
# ## Our Platform
#
# - **Models**: Explore a vast library of over **1 million models**, ranging from text generation to image processing.
# - **Datasets**: Access and share **over 250,000 datasets** suitable for various machine learning tasks.
# - **Spaces**: Utilize our collaborative environment to run AI applications and engage with the community.
# - **Open Source**: We contribute significantly to the open-source ecosystem, ensuring our tools and libraries remain accessible to developers around the globe.
#
# ## Community and Culture
#
# At Hugging Face, we believe that community drives innovation. We support a diverse ecosystem where over **50,000 organizations** collaborate, including prominent companies like Google, Microsoft, and Amazon. Collaboration is at our core, where individuals and teams can build their portfolios and share their work, all within a friendly and supportive environment.
#
# ### Our Values
#
# - **Collaboration**: We thrive on teamwork and the collective intelligence of our community.
# - **Innovation**: We are committed to using the latest technologies to develop cutting-edge AI tools.
# - **Accessibility**: We aim to make AI accessible for everyone, fostering learning and engagement across various skill levels.
#
# ## Career Opportunities
#
# Hugging Face is continuously on the lookout for passionate individuals who share our love for AI and technology. We offer a variety of roles suited for different skills and experiences, providing an enriching work environment where creativity and career development go hand in hand.
#
# ### Why Join Us?
#
# - **Work with Experts**: Collaborate with leading figures in the AI field.
# - **Flexibility**: Enjoy a supportive work environment that values work-life balance.
# - **Continuous Learning**: We encourage growth through ongoing learning and skill development.
#
# ## Get Involved
#
# Whether you’re a prospective customer interested in utilizing our platform, an investor looking to contribute to cutting-edge AI development, or a recruit passionate about technology, Hugging Face welcomes you!
#
# ### Contact Us
#
# - **Website**: [Hugging Face](https://huggingface.co)
# - **Follow Us**: Stay connected through [Twitter](https://twitter.com/huggingface), [LinkedIn](https://linkedin.com/company/huggingface), and [Discord](https://discord.gg/huggingface).
#
# Join us as we build the future of AI, together!
#
# ---
#
# ### Hugging Face - Empowering the AI Community

# %%
# Try changing the system prompt to the humorous version when you make the Brochure for Hugging Face:

stream_brochure("HuggingFace", "https://huggingface.co")
# Out:
# Found links: {'links': [{'type': 'about page', 'url': 'https://huggingface.co/huggingface'}, {'type': 'careers page', 'url': 'https://apply.workable.com/huggingface/'}, {'type': 'enterprise page', 'url': 'https://huggingface.co/enterprise'}, {'type': 'pricing page', 'url': 'https://huggingface.co/pricing'}, {'type': 'blog page', 'url': 'https://huggingface.co/blog'}, {'type': 'documentation page', 'url': 'https://huggingface.co/docs'}]}
# # Welcome to Hugging Face! 🤗
#
# Where AI dreams come true and models come to life – powered by an enthusiastic community of tech wizards!
#
# ---
#
# ### **What’s Hugging Face?**
# Imagine a cozy café where the future of artificial intelligence is brewed with a sprinkle of machine-learning magic! From models to datasets, we provide a platform where the **AI community** collaborates and innovates to build the future!
#
# ---
#
# ### **Our Offerings**
# - **Models Galore**: Over **1 million** models to choose from! Looking for a chatbot, image enhancer, or a machine learning wizard? You’ve come to the right place!
# - **Stacks on Stacks**: Our open-source stack is like an AI buffet where you can explore text, image, audio, and even 3D. Grab a plate and dig in!
#
# ---
#
# ### **Not Your Average Job**
# At Hugging Face, we don’t just work; we **collaborate** in a fun, engaging environment, fostering creativity and innovation like an overflowing Jenga tower of ideas! Whether you're a seasoned pro or just sorting out your first lines of code, we welcome you to come grow together with us.
#
# - **Flexible Work Culture**: Want to wear pajamas to a meeting? Go for it! We believe comfort breeds creativity (and who are we to judge?).
#
# - **Community Vibes**: With our chatty folks and AI enthusiasts, you’ll never have to drink coffee alone!
#
# ---
#
# ### **Join the Party!**
# Always wanted to work with cool AI tools? We offer roles to fit your skills and passions. Check out open positions and bring cuddles to the tech world!
#
# ---
#
# ### **Who Loves Us?**
# Over **50,000 organizations** can't seem to get enough of us, including giants like:
# - Google: 997 models (and counting, because they never stop)
# - Amazon: 20 models (FBA? Nah, We've Got Model Building!)
# - Microsoft: 386 models (the model mash-up continues)
#
# ---
#
# ### **Why Choose Hugging Face?**
# 1. **Unlimited Collaboration**: Because who doesn’t love a good buddy system?
# 2. **Always Growing**: We're on a quest to turn AI from "meh" to "wow!"
# 3. **Learning**: With amazing resources and documentation, we’re all in on this journey of discovery!
#
# ---
#
# ### **Dive In!**
# Ready to join the future builders? Don’t be a stranger! Reach out to us for services, support, or to say “Hi!”
#
# ---
#
# **Connect with us:**
# - GitHub: [Join Us](https://huggingface.co)
# - Twitter: [@HuggingFace](https://twitter.com/HuggingFace)
# - Discord: Enter the chat!
#
# Hugging Face – Building the future, one (hug)ging at a time! 🤗
#
# ---
#
# *Disclaimer: No actual hugging of AI models is encouraged.*

# %% [markdown]
# <table style="margin: 0; text-align: left;">
#     <tr>
#         <td style="width: 150px; height: 150px; vertical-align: middle;">
#             <img src="../business.jpg" width="150" height="150" style="display: block;" />
#         </td>
#         <td>
#             <h2 style="color:#181;">Business applications</h2>
#             <span style="color:#181;">In this exercise we extended the Day 1 code to make multiple LLM calls, and generate a document.
#
# This is perhaps the first example of Agentic AI design patterns, as we combined multiple calls to LLMs. This will feature more in Week 2, and then we will return to Agentic AI in a big way in Week 8 when we build a fully autonomous Agent solution.
#
# Generating content in this way is one of the very most common Use Cases. As with summarization, this can be applied to any business vertical. Write marketing content, generate a product tutorial from a spec, create personalized email content, and so much more. Explore how you can apply content generation to your business, and try making yourself a proof-of-concept prototype. See what other students have done in the community-contributions folder -- so many valuable projects -- it's wild!</span>
#         </td>
#     </tr>
# </table>

# %% [markdown]
# <table style="margin: 0; text-align: left;">
#     <tr>
#         <td style="width: 150px; height: 150px; vertical-align: middle;">
#             <img src="../important.jpg" width="150" height="150" style="display: block;" />
#         </td>
#         <td>
#             <h2 style="color:#900;">Before you move to Week 2 (which is tons of fun)</h2>
#             <span style="color:#900;">Please see the week1 EXERCISE notebook for your challenge for the end of week 1. This will give you some essential practice working with Frontier APIs, and prepare you well for Week 2.</span>
#         </td>
#     </tr>
# </table>

# %% [markdown]
# <table style="margin: 0; text-align: left;">
#     <tr>
#         <td style="width: 150px; height: 150px; vertical-align: middle;">
#             <img src="../resources.jpg" width="150" height="150" style="display: block;" />
#         </td>
#         <td>
#             <h2 style="color:#f71;">A reminder on 3 useful resources</h2>
#             <span style="color:#f71;">1. The resources for the course are available <a href="https://edwarddonner.com/2024/11/13/llm-engineering-resources/">here.</a><br/>
#             2. I'm on LinkedIn <a href="https://www.linkedin.com/in/eddonner/">here</a> and I love connecting with people taking the course!<br/>
#             3. I'm trying out X/Twitter and I'm at <a href="https://x.com/edwarddonner">@edwarddonner<a> and hoping people will teach me how it's done..
#             </span>
#         </td>
#     </tr>
# </table>

# %% [markdown]
# <table style="margin: 0; text-align: left;">
#     <tr>
#         <td style="width: 150px; height: 150px; vertical-align: middle;">
#             <img src="../thankyou.jpg" width="150" height="150" style="display: block;" />
#         </td>
#         <td>
#             <h2 style="color:#090;">Finally! I have a special request for you</h2>
#             <span style="color:#090;">
#                 My editor tells me that it makes a MASSIVE difference when students rate this course on Udemy - it's one of the main ways that Udemy decides whether to show it to others. If you're able to take a minute to rate this, I'd be so very grateful! And regardless - always please reach out to me at ed@edwarddonner.com if I can help at any point.
#             </span>
#         </td>
#     </tr>
# </table>
